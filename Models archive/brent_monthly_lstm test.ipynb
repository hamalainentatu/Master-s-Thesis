# %%
# Start loading libraries

#! pip install yfinance

# ! conda install seaborn

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import scipy
import scipy.stats as stats
import statsmodels.api as sm

import scipy
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

import pmdarima as pm
from pmdarima import model_selection
from pmdarima.model_selection import SlidingWindowForecastCV

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


from scipy.optimize import minimize
from random import gauss
import math
from statistics import mean, stdev

from numpy import asarray
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot


#! pip install tensorflow --user
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Input
from sklearn.preprocessing import MinMaxScaler

#from statsmodels.graphics.tsaplots import plot_acf

#from matplotlib.ticker import NullFormatter
#import yfinance as yf
#import warnings; warnings.simplefilter('ignore')
#%matplotlib inline

# %%
xls_file = pd.ExcelFile("Data_monthly_final.xlsx") # Read Excel
df1=xls_file.parse("Brent") # Read the first sheet (Portfolio holdings)

#df1["Timestamp"] = df1["Date"].astype('datetime64[ns]') # Convert column to date format
df1 = df1.set_index(['Timestamp']) # use first column as index

#df1.to_excel("values.xlsx")  #print to excel

# %%
spot = df1["LCOc1"]
spot = np.log(spot)
spot = spot.loc['2004-01-31':'2022-11-30']
spot_train = spot.loc[:'2016-07-31']
#spot_train.plot()

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
 #n_vars = 1 if type(data) is list else data.shape[1]
 df_temp = pd.DataFrame(data)
 cols = list()
 # input sequence (t-n, ... t-1)
 for i in range(n_in, 0, -1):
    cols.append(df_temp.shift(i))
 # forecast sequence (t, t+1, ... t+n)
 for i in range(0, n_out):
    cols.append(df_temp.shift(-i))
 # put it all together
 agg = pd.concat(cols, axis=1)
 # drop rows with NaN values
 if dropnan:
    agg.dropna(inplace=True)
 return agg.values

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# Load the data and split it into separate pieces
data = np.array(spot.dropna())
train, test = model_selection.train_test_split(data, train_size=(spot_train.shape[0]))

# normalize the dataset
scaler1 = MinMaxScaler(feature_range=(0, 1)).fit(train.reshape(-1, 1))  ### using only train data in the scaling
data_scaled = scaler1.transform(data.reshape(-1, 1))

time_lag = 12

data_new = series_to_supervised(data_scaled, n_in=time_lag, n_out=1, dropnan=True)
#train, test = model_selection.train_test_split(data, train_size=(spot.shape[0]-1))

# %%
#data_scaled1 = scaler1.inverse_transform(data_scaled)
#np.exp(data_scaled1)

# %%
#train_new  = series_to_supervised(train, n_in=time_lag, n_out=1, dropnan=True)
#test_new = series_to_supervised(test, n_in=time_lag, n_out=1, dropnan=True)

# %%
predictions = list()
# split dataset
train1, test1 = train_test_split(data_new, len(test))
# seed history with training dataset
history = [x for x in train1]
# step over each time-step in the test set
# split test row into input and output columns
testX, testy = test1[0, :-1], test1[0, -1]
# fit model on history and make a prediction
#yhat = lstm_forecast(history, testX)
# store forecast in list of predictions


trainlocal = history

# transform list into array
trainlocalar = asarray(trainlocal)
# split into input and output columns
trainX, trainy = trainlocalar[:, :-1], trainlocalar[:, -1]

# reshape input to be [samples, time steps, features]
#print(trainX)
#trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1] , 1))
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
#print(trainX.shape)
#print(trainX)
print(testX)
testX = np.reshape(testX, (1, testX.shape[0], 1))    
#print(testX.shape)

# create and fit the LSTM network
model = Sequential()
#model.add(InputLayer((time_lag,1)))
model.add(InputLayer((time_lag,1)))
model.add(LSTM(4))
#model.add(LSTM(4))
#model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainy, validation_split=0.33, epochs=100, batch_size=1, verbose=2, shuffle=False)
#model.fit(trainX, trainy, epochs=100, batch_size=1, verbose=2)
#model.fit(trainX, trainy, epochs=1, batch_size=1, verbose=2)

# make a one-step prediction
yhat = model.predict(testX)

predictions.append(yhat)
# add actual observation to history for the next loop and delete oldest one
#history.append(test1[i])
#history.pop(0)
# summarize progress
print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
# Out:
# [0.39457344 0.32253628 0.3380469  0.27089325 0.15633837 0.1113047
#  0.13350939 0.19486695 0.31936188 0.33971872 0.33959027 0.23936972]
# Epoch 1/100
# 93/93 - 2s - loss: 0.0339 - val_loss: 0.0443 - 2s/epoch - 24ms/step
# Epoch 2/100
# 93/93 - 1s - loss: 0.0317 - val_loss: 0.0695 - 651ms/epoch - 7ms/step
# Epoch 3/100
# 93/93 - 0s - loss: 0.0348 - val_loss: 0.0380 - 477ms/epoch - 5ms/step
# Epoch 4/100
# 93/93 - 0s - loss: 0.0277 - val_loss: 0.0661 - 461ms/epoch - 5ms/step
# Epoch 5/100
# 93/93 - 0s - loss: 0.0226 - val_loss: 0.0582 - 444ms/epoch - 5ms/step
# Epoch 6/100
# 93/93 - 0s - loss: 0.0196 - val_loss: 0.0468 - 416ms/epoch - 4ms/step
# Epoch 7/100
# 93/93 - 0s - loss: 0.0171 - val_loss: 0.0397 - 441ms/epoch - 5ms/step
# Epoch 8/100
# 93/93 - 0s - loss: 0.0151 - val_loss: 0.0339 - 428ms/epoch - 5ms/step
# Epoch 9/100
# 93/93 - 0s - loss: 0.0133 - val_loss: 0.0290 - 427ms/epoch - 5ms/step
# Epoch 10/100
# 93/93 - 0s - loss: 0.0118 - val_loss: 0.0248 - 450ms/epoch - 5ms/step
# Epoch 11/100
# 93/93 - 0s - loss: 0.0105 - val_loss: 0.0214 - 439ms/epoch - 5ms/step
# Epoch 12/100
# 93/93 - 0s - loss: 0.0093 - val_loss: 0.0187 - 446ms/epoch - 5ms/step
# Epoch 13/100
# 93/93 - 0s - loss: 0.0083 - val_loss: 0.0165 - 425ms/epoch - 5ms/step
# Epoch 14/100
# 93/93 - 0s - loss: 0.0075 - val_loss: 0.0143 - 417ms/epoch - 4ms/step
# Epoch 15/100
# 93/93 - 0s - loss: 0.0069 - val_loss: 0.0132 - 456ms/epoch - 5ms/step
# Epoch 16/100
# 93/93 - 0s - loss: 0.0064 - val_loss: 0.0125 - 446ms/epoch - 5ms/step
# Epoch 17/100
# 93/93 - 0s - loss: 0.0061 - val_loss: 0.0119 - 455ms/epoch - 5ms/step
# Epoch 18/100
# 93/93 - 0s - loss: 0.0058 - val_loss: 0.0110 - 421ms/epoch - 5ms/step
# Epoch 19/100
# 93/93 - 0s - loss: 0.0055 - val_loss: 0.0105 - 427ms/epoch - 5ms/step
# Epoch 20/100
# 93/93 - 0s - loss: 0.0053 - val_loss: 0.0104 - 429ms/epoch - 5ms/step
# Epoch 21/100
# 93/93 - 0s - loss: 0.0051 - val_loss: 0.0100 - 426ms/epoch - 5ms/step
# Epoch 22/100
# 93/93 - 0s - loss: 0.0050 - val_loss: 0.0092 - 434ms/epoch - 5ms/step
# Epoch 23/100
# 93/93 - 0s - loss: 0.0048 - val_loss: 0.0087 - 429ms/epoch - 5ms/step
# Epoch 24/100
# 93/93 - 1s - loss: 0.0046 - val_loss: 0.0086 - 529ms/epoch - 6ms/step
# Epoch 25/100
# 93/93 - 1s - loss: 0.0045 - val_loss: 0.0086 - 506ms/epoch - 5ms/step
# Epoch 26/100
# 93/93 - 0s - loss: 0.0044 - val_loss: 0.0083 - 464ms/epoch - 5ms/step
# Epoch 27/100
# 93/93 - 0s - loss: 0.0043 - val_loss: 0.0078 - 426ms/epoch - 5ms/step
# Epoch 28/100
# 93/93 - 0s - loss: 0.0042 - val_loss: 0.0078 - 467ms/epoch - 5ms/step
# Epoch 29/100
# 93/93 - 0s - loss: 0.0041 - val_loss: 0.0079 - 429ms/epoch - 5ms/step
# Epoch 30/100
# 93/93 - 0s - loss: 0.0041 - val_loss: 0.0076 - 429ms/epoch - 5ms/step
# Epoch 31/100
# 93/93 - 0s - loss: 0.0040 - val_loss: 0.0072 - 437ms/epoch - 5ms/step
# Epoch 32/100
# 93/93 - 0s - loss: 0.0039 - val_loss: 0.0070 - 427ms/epoch - 5ms/step
# Epoch 33/100
# 93/93 - 0s - loss: 0.0038 - val_loss: 0.0071 - 455ms/epoch - 5ms/step
# Epoch 34/100
# 93/93 - 0s - loss: 0.0038 - val_loss: 0.0072 - 428ms/epoch - 5ms/step
# Epoch 35/100
# 93/93 - 0s - loss: 0.0038 - val_loss: 0.0073 - 482ms/epoch - 5ms/step
# Epoch 36/100
# 93/93 - 1s - loss: 0.0037 - val_loss: 0.0072 - 502ms/epoch - 5ms/step
# Epoch 37/100
# 93/93 - 1s - loss: 0.0037 - val_loss: 0.0071 - 508ms/epoch - 5ms/step
# Epoch 38/100
# 93/93 - 1s - loss: 0.0036 - val_loss: 0.0069 - 520ms/epoch - 6ms/step
# Epoch 39/100
# 93/93 - 1s - loss: 0.0036 - val_loss: 0.0070 - 529ms/epoch - 6ms/step
# Epoch 40/100
# 93/93 - 1s - loss: 0.0036 - val_loss: 0.0069 - 518ms/epoch - 6ms/step
# Epoch 41/100
# 93/93 - 1s - loss: 0.0036 - val_loss: 0.0070 - 590ms/epoch - 6ms/step
# Epoch 42/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0071 - 523ms/epoch - 6ms/step
# Epoch 43/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0073 - 501ms/epoch - 5ms/step
# Epoch 44/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0073 - 491ms/epoch - 5ms/step
# Epoch 45/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0074 - 494ms/epoch - 5ms/step
# Epoch 46/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0075 - 494ms/epoch - 5ms/step
# Epoch 47/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0072 - 572ms/epoch - 6ms/step
# Epoch 48/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0074 - 556ms/epoch - 6ms/step
# Epoch 49/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0074 - 558ms/epoch - 6ms/step
# Epoch 50/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0073 - 510ms/epoch - 5ms/step
# Epoch 51/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0081 - 515ms/epoch - 6ms/step
# Epoch 52/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0082 - 513ms/epoch - 6ms/step
# Epoch 53/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0082 - 544ms/epoch - 6ms/step
# Epoch 54/100
# 93/93 - 1s - loss: 0.0034 - val_loss: 0.0091 - 530ms/epoch - 6ms/step
# Epoch 55/100
# 93/93 - 1s - loss: 0.0034 - val_loss: 0.0090 - 573ms/epoch - 6ms/step
# Epoch 56/100
# 93/93 - 1s - loss: 0.0035 - val_loss: 0.0085 - 536ms/epoch - 6ms/step
# Epoch 57/100
# 93/93 - 0s - loss: 0.0033 - val_loss: 0.0095 - 460ms/epoch - 5ms/step
# Epoch 58/100
# 93/93 - 1s - loss: 0.0034 - val_loss: 0.0090 - 516ms/epoch - 6ms/step
# Epoch 59/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0078 - 465ms/epoch - 5ms/step
# Epoch 60/100
# 93/93 - 0s - loss: 0.0034 - val_loss: 0.0087 - 478ms/epoch - 5ms/step
# Epoch 61/100
# 93/93 - 0s - loss: 0.0036 - val_loss: 0.0102 - 461ms/epoch - 5ms/step
# Epoch 62/100
# 93/93 - 0s - loss: 0.0033 - val_loss: 0.0106 - 433ms/epoch - 5ms/step
# Epoch 63/100
# 93/93 - 0s - loss: 0.0034 - val_loss: 0.0086 - 437ms/epoch - 5ms/step
# Epoch 64/100
# 93/93 - 0s - loss: 0.0037 - val_loss: 0.0083 - 438ms/epoch - 5ms/step
# Epoch 65/100
# 93/93 - 0s - loss: 0.0066 - val_loss: 0.0148 - 460ms/epoch - 5ms/step
# Epoch 66/100
# 93/93 - 0s - loss: 0.0042 - val_loss: 0.0126 - 469ms/epoch - 5ms/step
# Epoch 67/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0132 - 433ms/epoch - 5ms/step
# Epoch 68/100
# 93/93 - 0s - loss: 0.0043 - val_loss: 0.0102 - 428ms/epoch - 5ms/step
# Epoch 69/100
# 93/93 - 0s - loss: 0.0038 - val_loss: 0.0107 - 483ms/epoch - 5ms/step
# Epoch 70/100
# 93/93 - 0s - loss: 0.0037 - val_loss: 0.0095 - 465ms/epoch - 5ms/step
# Epoch 71/100
# 93/93 - 0s - loss: 0.0037 - val_loss: 0.0088 - 452ms/epoch - 5ms/step
# Epoch 72/100
# 93/93 - 0s - loss: 0.0034 - val_loss: 0.0083 - 430ms/epoch - 5ms/step
# Epoch 73/100
# 93/93 - 0s - loss: 0.0035 - val_loss: 0.0077 - 433ms/epoch - 5ms/step
# Epoch 74/100
# 93/93 - 0s - loss: 0.0032 - val_loss: 0.0076 - 439ms/epoch - 5ms/step
# Epoch 75/100
# 93/93 - 0s - loss: 0.0032 - val_loss: 0.0074 - 428ms/epoch - 5ms/step
# Epoch 76/100
# 93/93 - 0s - loss: 0.0032 - val_loss: 0.0074 - 433ms/epoch - 5ms/step
# Epoch 77/100
# 93/93 - 0s - loss: 0.0031 - val_loss: 0.0073 - 424ms/epoch - 5ms/step
# Epoch 78/100
# 93/93 - 0s - loss: 0.0031 - val_loss: 0.0073 - 464ms/epoch - 5ms/step
# Epoch 79/100
# 93/93 - 0s - loss: 0.0031 - val_loss: 0.0072 - 428ms/epoch - 5ms/step
# Epoch 80/100
# 93/93 - 0s - loss: 0.0031 - val_loss: 0.0072 - 442ms/epoch - 5ms/step
# Epoch 81/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0071 - 487ms/epoch - 5ms/step
# Epoch 82/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0071 - 497ms/epoch - 5ms/step
# Epoch 83/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0070 - 490ms/epoch - 5ms/step
# Epoch 84/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0069 - 476ms/epoch - 5ms/step
# Epoch 85/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0069 - 479ms/epoch - 5ms/step
# Epoch 86/100
# 93/93 - 0s - loss: 0.0030 - val_loss: 0.0068 - 490ms/epoch - 5ms/step
# Epoch 87/100
# 93/93 - 1s - loss: 0.0030 - val_loss: 0.0068 - 611ms/epoch - 7ms/step
# Epoch 88/100
# 93/93 - 1s - loss: 0.0030 - val_loss: 0.0067 - 608ms/epoch - 7ms/step
# Epoch 89/100
# 93/93 - 0s - loss: 0.0029 - val_loss: 0.0067 - 489ms/epoch - 5ms/step
# Epoch 90/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0067 - 536ms/epoch - 6ms/step
# Epoch 91/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0066 - 581ms/epoch - 6ms/step
# Epoch 92/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0067 - 605ms/epoch - 7ms/step
# Epoch 93/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0066 - 607ms/epoch - 7ms/step
# Epoch 94/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0067 - 531ms/epoch - 6ms/step
# Epoch 95/100
# 93/93 - 0s - loss: 0.0029 - val_loss: 0.0066 - 493ms/epoch - 5ms/step
# Epoch 96/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0067 - 586ms/epoch - 6ms/step
# Epoch 97/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0066 - 508ms/epoch - 5ms/step
# Epoch 98/100
# 93/93 - 0s - loss: 0.0029 - val_loss: 0.0067 - 492ms/epoch - 5ms/step
# Epoch 99/100
# 93/93 - 1s - loss: 0.0029 - val_loss: 0.0065 - 537ms/epoch - 6ms/step
# Epoch 100/100
# 93/93 - 0s - loss: 0.0029 - val_loss: 0.0067 - 460ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 398ms/step
# >expected=0.3, predicted=0.3
# C:\Users\tatuh\AppData\Local\Temp\ipykernel_12860\3564999081.py:52: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('>expected=%.1f, predicted=%.1f' % (testy, yhat))

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
len(testX)
# Out:
# 1

# %%
# create and fit the LSTM network
model = Sequential()
#model.add(InputLayer((time_lag,1)))
model.add(InputLayer((time_lag,1)))
model.add(LSTM(256))
#model.add(LSTM(4))
#model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 256)               264192
#
#  dense_7 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create and fit the LSTM network
model = Sequential()
model.add(Input((time_lag,1)))
#model.add(InputLayer((time_lag,1)))
model.add(LSTM(256))
#model.add(LSTM(4))
#model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 256)               264192
#
#  dense_8 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
# create and fit the LSTM network
model = Sequential()
#model.add(Input((time_lag,1)))
#model.add(InputLayer((time_lag,1)))
model.add(LSTM(256, input_shape=(time_lag,1)))
#model.add(LSTM(4))
#model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
model.add(Dense(1))

model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 256)               264192
#
#  dense_9 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 264,449
# Trainable params: 264,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit an lstm model and make a one step prediction
def lstm_forecast(trainlocal, testX):
 # transform list into array
 trainlocalar = asarray(trainlocal)
 # split into input and output columns
 trainX, trainy = trainlocalar[:, :-1], trainlocalar[:, -1]

 # reshape input to be [samples, time steps, features]
 trainX = np.reshape(trainX, (trainX.shape[0], 1 , trainX.shape[1]))
 print(trainX)
 testX = np.reshape(testX, (testX.shape[0], 1 , trainX.shape[1]))     #### PURKKARATKAISU ###
 print(trainy)

 # create and fit the LSTM network
 model = Sequential()
 #model.add(InputLayer((time_lag,1)))
 model.add(InputLayer((time_lag,1)))
 model.add(LSTM(256))
 #model.add(LSTM(4))
 #model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
 model.add(Dense(1))
 model.compile(loss='mean_squared_error', optimizer='adam')
 model.fit(trainX, trainy, epochs=100, batch_size=1, verbose=2)
 #model.fit(trainX, trainy, epochs=1, batch_size=1, verbose=2)
 
  # make a one-step prediction
 yhat = model.predict([testX])
 return yhat[0]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
   predictions = list()
   # split dataset
   train1, test1 = train_test_split(data, n_test)
   # seed history with training dataset
   history = [x for x in train1]
   # step over each time-step in the test set
   for i in range(len(test1)):
      # split test row into input and output columns
      testX, testy = test1[i, :-1], test1[i, -1]
      # fit model on history and make a prediction
      yhat = lstm_forecast(history, testX)
      # store forecast in list of predictions
      predictions.append(yhat)
      # add actual observation to history for the next loop and delete oldest one
      history.append(test1[i])
      history.pop(0)
      # summarize progress
      print('>expected=%.1f, predicted=%.1f' % (testy, yhat))

    # estimate prediction error
   error = mean_absolute_error(test1[:, -1], predictions)
   return error, test1[:, -1], predictions

# %%
# evaluate
#mae, y, yhat = walk_forward_validation(data_new, len(test))
mae, y, yhat = walk_forward_validation(data_new, 1)
print('MAE: %.3f' % mae)
# Out:
# [[[ 0.          0.06344462  0.04902627]]
#
#  [[ 0.06344462  0.04902627  0.10651045]]
#
#  [[ 0.04902627  0.10651045  0.14424135]]
#
#  [[ 0.10651045  0.14424135  0.10688052]]
#
#  [[ 0.14424135  0.10688052  0.20175939]]
#
#  [[ 0.10688052  0.20175939  0.19502809]]
#
#  [[ 0.20175939  0.19502809  0.2957252 ]]
#
#  [[ 0.19502809  0.2957252   0.33053418]]
#
#  [[ 0.2957252   0.33053418  0.28364037]]
#
#  [[ 0.33053418  0.28364037  0.20857817]]
#
#  [[ 0.28364037  0.20857817  0.28936404]]
#
#  [[ 0.20857817  0.28936404  0.34445315]]
#
#  [[ 0.28936404  0.34445315  0.39622128]]
#
#  [[ 0.34445315  0.39622128  0.35745074]]
#
#  [[ 0.39622128  0.35745074  0.35293792]]
#
#  [[ 0.35745074  0.35293792  0.41120802]]
#
#  [[ 0.35293792  0.41120802  0.45330629]]
#
#  [[ 0.41120802  0.45330629  0.5306556 ]]
#
#  [[ 0.45330629  0.5306556   0.49602374]]
#
#  [[ 0.5306556   0.49602374  0.43950657]]
#
#  [[ 0.49602374  0.43950657  0.40509321]]
#
#  [[ 0.43950657  0.40509321  0.44910024]]
#
#  [[ 0.40509321  0.44910024  0.52077148]]
#
#  [[ 0.44910024  0.52077148  0.47849344]]
#
#  [[ 0.52077148  0.47849344  0.51999734]]
#
#  [[ 0.47849344  0.51999734  0.58081406]]
#
#  [[ 0.51999734  0.58081406  0.56214634]]
#
#  [[ 0.58081406  0.56214634  0.58964328]]
#
#  [[ 0.56214634  0.58964328  0.60372461]]
#
#  [[ 0.58964328  0.60372461  0.56069448]]
#
#  [[ 0.60372461  0.56069448  0.48589039]]
#
#  [[ 0.56069448  0.48589039  0.44964103]]
#
#  [[ 0.48589039  0.44964103  0.50381755]]
#
#  [[ 0.44964103  0.50381755  0.46912504]]
#
#  [[ 0.50381755  0.46912504  0.4317709 ]]
#
#  [[ 0.46912504  0.4317709   0.47983536]]
#
#  [[ 0.4317709   0.47983536  0.54085771]]
#
#  [[ 0.47983536  0.54085771  0.53662664]]
#
#  [[ 0.54085771  0.53662664  0.54029519]]
#
#  [[ 0.53662664  0.54029519  0.57114642]]
#
#  [[ 0.54029519  0.57114642  0.6196591 ]]
#
#  [[ 0.57114642  0.6196591   0.58248435]]
#
#  [[ 0.6196591   0.58248435  0.63698128]]
#
#  [[ 0.58248435  0.63698128  0.72325612]]
#
#  [[ 0.63698128  0.72325612  0.70634532]]
#
#  [[ 0.72325612  0.70634532  0.74553674]]
#
#  [[ 0.70634532  0.74553674  0.73428607]]
#
#  [[ 0.74553674  0.73428607  0.78668176]]
#
#  [[ 0.73428607  0.78668176  0.78795558]]
#
#  [[ 0.78668176  0.78795558  0.85471132]]
#
#  [[ 0.78795558  0.85471132  0.94248845]]
#
#  [[ 0.85471132  0.94248845  1.        ]]
#
#  [[ 0.94248845  1.          0.92322179]]
#
#  [[ 1.          0.92322179  0.869944  ]]
#
#  [[ 0.92322179  0.869944    0.77425692]]
#
#  [[ 0.869944    0.77425692  0.51425884]]
#
#  [[ 0.77425692  0.51425884  0.38674722]]
#
#  [[ 0.51425884  0.38674722  0.28476122]]
#
#  [[ 0.38674722  0.28476122  0.28880789]]
#
#  [[ 0.28476122  0.28880789  0.29531227]]
#
#  [[ 0.28880789  0.29531227  0.33378327]]
#
#  [[ 0.29531227  0.33378327  0.35381792]]
#
#  [[ 0.33378327  0.35381792  0.51620988]]
#
#  [[ 0.35381792  0.51620988  0.55200533]]
#
#  [[ 0.51620988  0.55200533  0.57373288]]
#
#  [[ 0.55200533  0.57373288  0.55522038]]
#
#  [[ 0.57373288  0.55522038  0.54988373]]
#
#  [[ 0.55522038  0.54988373  0.60414908]]
#
#  [[ 0.54988373  0.60414908  0.63131352]]
#
#  [[ 0.60414908  0.63131352  0.6269066 ]]
#
#  [[ 0.63131352  0.6269066   0.57159311]]
#
#  [[ 0.6269066   0.57159311  0.62411618]]
#
#  [[ 0.57159311  0.62411618  0.66482028]]
#
#  [[ 0.62411618  0.66482028  0.7003884 ]]
#
#  [[ 0.66482028  0.7003884   0.59946435]]
#
#  [[ 0.7003884   0.59946435  0.6025346 ]]
#
#  [[ 0.59946435  0.6025346   0.62895062]]
#
#  [[ 0.6025346   0.62895062  0.59937885]]
#
#  [[ 0.62895062  0.59937885  0.66180359]]
#
#  [[ 0.59937885  0.66180359  0.66828346]]
#
#  [[ 0.66180359  0.66828346  0.68919705]]
#
#  [[ 0.66828346  0.68919705  0.75162763]]
#
#  [[ 0.68919705  0.75162763  0.79245722]]
#
#  [[ 0.75162763  0.79245722  0.85722792]]
#
#  [[ 0.79245722  0.85722792  0.88820195]]
#
#  [[ 0.85722792  0.88820195  0.93297852]]
#
#  [[ 0.88820195  0.93297852  0.88476688]]
#
#  [[ 0.93297852  0.88476688  0.86109779]]
#
#  [[ 0.88476688  0.86109779  0.88482155]]
#
#  [[ 0.86109779  0.88482155  0.8744049 ]]
#
#  [[ 0.88482155  0.8744049   0.8034191 ]]
#
#  [[ 0.8744049   0.8034191   0.84431155]]
#
#  [[ 0.8034191   0.84431155  0.84987918]]
#
#  [[ 0.84431155  0.84987918  0.83148506]]
#
#  [[ 0.84987918  0.83148506  0.85252988]]
#
#  [[ 0.83148506  0.85252988  0.91639069]]
#
#  [[ 0.85252988  0.91639069  0.9175343 ]]
#
#  [[ 0.91639069  0.9175343   0.89957387]]
#
#  [[ 0.9175343   0.89957387  0.79786774]]
#
#  [[ 0.89957387  0.79786774  0.77184708]]
#
#  [[ 0.79786774  0.77184708  0.81669462]]
#
#  [[ 0.77184708  0.81669462  0.87284713]]
#
#  [[ 0.81669462  0.87284713  0.86058694]]
#
#  [[ 0.87284713  0.86058694  0.8392823 ]]
#
#  [[ 0.86058694  0.8392823   0.85396588]]
#
#  [[ 0.8392823   0.85396588  0.853277  ]]
#
#  [[ 0.85396588  0.853277    0.87828277]]
#
#  [[ 0.853277    0.87828277  0.85482593]]
#
#  [[ 0.87828277  0.85482593  0.84698544]]
#
#  [[ 0.85482593  0.84698544  0.80099242]]
#
#  [[ 0.84698544  0.80099242  0.78852797]]
#
#  [[ 0.80099242  0.78852797  0.79968192]]
#
#  [[ 0.78852797  0.79968192  0.83338407]]
#
#  [[ 0.79968192  0.83338407  0.86972013]]
#
#  [[ 0.83338407  0.86972013  0.83734191]]
#
#  [[ 0.86972013  0.83734191  0.84010373]]
#
#  [[ 0.83734191  0.84010373  0.84506835]]
#
#  [[ 0.84010373  0.84506835  0.85149396]]
#
#  [[ 0.84506835  0.85149396  0.82563394]]
#
#  [[ 0.85149396  0.82563394  0.84145091]]
#
#  [[ 0.82563394  0.84145091  0.8337395 ]]
#
#  [[ 0.84145091  0.8337395   0.83557277]]
#
#  [[ 0.8337395   0.83557277  0.84343721]]
#
#  [[ 0.83557277  0.84343721  0.86041657]]
#
#  [[ 0.84343721  0.86041657  0.82335063]]
#
#  [[ 0.86041657  0.82335063  0.80608402]]
#
#  [[ 0.82335063  0.80608402  0.75108857]]
#
#  [[ 0.80608402  0.75108857  0.68875124]]
#
#  [[ 0.75108857  0.68875124  0.55978538]]
#
#  [[ 0.68875124  0.55978538  0.43099215]]
#
#  [[ 0.55978538  0.43099215  0.3807537 ]]
#
#  [[ 0.43099215  0.3807537   0.486911  ]]
#
#  [[ 0.3807537   0.486911    0.4057884 ]]
#
#  [[ 0.486911    0.4057884   0.52836615]]
#
#  [[ 0.4057884   0.52836615  0.51659937]]
#
#  [[ 0.52836615  0.51659937  0.49712865]]
#
#  [[ 0.51659937  0.49712865  0.37128995]]
#
#  [[ 0.49712865  0.37128995  0.39457344]]
#
#  [[ 0.37128995  0.39457344  0.32253628]]
#
#  [[ 0.39457344  0.32253628  0.3380469 ]]
#
#  [[ 0.32253628  0.3380469   0.27089325]]
#
#  [[ 0.3380469   0.27089325  0.15633837]]
#
#  [[ 0.27089325  0.15633837  0.1113047 ]]
#
#  [[ 0.15633837  0.1113047   0.13350939]]
#
#  [[ 0.1113047   0.13350939  0.19486695]]
#
#  [[ 0.13350939  0.19486695  0.31936188]]
#
#  [[ 0.19486695  0.31936188  0.33971872]]
#
#  [[ 0.31936188  0.33971872  0.33959027]]
#
#  [[ 0.33971872  0.33959027  0.23936972]]
#
#  [[ 0.33959027  0.23936972  0.30474274]]
#
#  [[ 0.23936972  0.30474274  0.33157569]]
#
#  [[ 0.30474274  0.33157569  0.32161204]]
#
#  [[ 0.33157569  0.32161204  0.3496587 ]]
#
#  [[ 0.32161204  0.3496587   0.42528954]]
#
#  [[ 0.3496587   0.42528954  0.41258441]]
#
#  [[ 0.42528954  0.41258441  0.41132283]]
#
#  [[ 0.41258441  0.41132283  0.37882383]]
#
#  [[ 0.41132283  0.37882383  0.36539557]]
#
#  [[ 0.37882383  0.36539557  0.34763232]]
#
#  [[ 0.36539557  0.34763232  0.31657127]]
#
#  [[ 0.34763232  0.31657127  0.37664572]]
#
#  [[ 0.31657127  0.37664572  0.37336456]]
#
#  [[ 0.37664572  0.37336456  0.43332555]]
#
#  [[ 0.37336456  0.43332555  0.47445068]]
#
#  [[ 0.43332555  0.47445068  0.4969279 ]]
#
#  [[ 0.47445068  0.4969279   0.52922566]]
#
#  [[ 0.4969279   0.52922566  0.54969891]]
#
#  [[ 0.52922566  0.54969891  0.51873735]]
#
#  [[ 0.54969891  0.51873735  0.56087614]]
#
#  [[ 0.51873735  0.56087614  0.60389443]]
#
#  [[ 0.56087614  0.60389443  0.62411618]]
#
#  [[ 0.60389443  0.62411618  0.63915403]]
#
#  [[ 0.62411618  0.63915403  0.59603554]]
#
#  [[ 0.63915403  0.59603554  0.62271638]]
#
#  [[ 0.59603554  0.62271638  0.6649746 ]]
#
#  [[ 0.62271638  0.6649746   0.60643633]]
#
#  [[ 0.6649746   0.60643633  0.44617203]]
#
#  [[ 0.60643633  0.44617203  0.39043513]]
#
#  [[ 0.44617203  0.39043513  0.47983536]]
#
#  [[ 0.39043513  0.47983536  0.5211582 ]]
#
#  [[ 0.47983536  0.5211582   0.54356962]]
#
#  [[ 0.5211582   0.54356962  0.58344937]]
#
#  [[ 0.54356962  0.58344937  0.50609767]]
#
#  [[ 0.58344937  0.50609767  0.52616435]]
#
#  [[ 0.50609767  0.52616435  0.51279163]]
#
#  [[ 0.52616435  0.51279163  0.46460001]]
#
#  [[ 0.51279163  0.46460001  0.4682856 ]]
#
#  [[ 0.46460001  0.4682856   0.46248436]]
#
#  [[ 0.4682856   0.46248436  0.48537947]]
#
#  [[ 0.46248436  0.48537947  0.52086818]]
#
#  [[ 0.48537947  0.52086818  0.44016529]]
#
#  [[ 0.52086818  0.44016529  0.35029063]]
#
#  [[ 0.44016529  0.35029063 -0.15913656]]
#
#  [[ 0.35029063 -0.15913656 -0.09181288]]
#
#  [[-0.15913656 -0.09181288  0.12205218]]
#
#  [[-0.09181288  0.12205218  0.21936994]]
#
#  [[ 0.12205218  0.21936994  0.25187188]]
#
#  [[ 0.21936994  0.25187188  0.28040691]]
#
#  [[ 0.25187188  0.28040691  0.21626063]]
#
#  [[ 0.28040691  0.21626063  0.15941232]]
#
#  [[ 0.21626063  0.15941232  0.31216122]]
#
#  [[ 0.15941232  0.31216122  0.36625856]]
#
#  [[ 0.31216122  0.36625856  0.41464344]]
#
#  [[ 0.36625856  0.41464344  0.52212398]]
#
#  [[ 0.41464344  0.52212398  0.49662665]]
#
#  [[ 0.52212398  0.49662665  0.53284199]]
#
#  [[ 0.49662665  0.53284199  0.55218949]]
#
#  [[ 0.53284199  0.55218949  0.60355475]]
#
#  [[ 0.55218949  0.60355475  0.61366749]]
#
#  [[ 0.60355475  0.61366749  0.5851128 ]]
#
#  [[ 0.61366749  0.5851128   0.63172003]]
#
#  [[ 0.5851128   0.63172003  0.6776547 ]]
#
#  [[ 0.63172003  0.6776547   0.56359491]]
#
#  [[ 0.6776547   0.56359491  0.62567703]]
#
#  [[ 0.56359491  0.62567703  0.72732727]]
#
#  [[ 0.62567703  0.72732727  0.79233085]]
#
#  [[ 0.72732727  0.79233085  0.83462723]]
#
#  [[ 0.79233085  0.83462723  0.84302877]]
#
#  [[ 0.83462723  0.84302877  0.91732652]]
#
#  [[ 0.84302877  0.91732652  0.87418259]]
#
#  [[ 0.91732652  0.87418259  0.84692743]]
#
#  [[ 0.87418259  0.84692743  0.76324102]]
#
#  [[ 0.84692743  0.76324102  0.7041724 ]]]
# [ 0.10651045  0.14424135  0.10688052  0.20175939  0.19502809  0.2957252
#   0.33053418  0.28364037  0.20857817  0.28936404  0.34445315  0.39622128
#   0.35745074  0.35293792  0.41120802  0.45330629  0.5306556   0.49602374
#   0.43950657  0.40509321  0.44910024  0.52077148  0.47849344  0.51999734
#   0.58081406  0.56214634  0.58964328  0.60372461  0.56069448  0.48589039
#   0.44964103  0.50381755  0.46912504  0.4317709   0.47983536  0.54085771
#   0.53662664  0.54029519  0.57114642  0.6196591   0.58248435  0.63698128
#   0.72325612  0.70634532  0.74553674  0.73428607  0.78668176  0.78795558
#   0.85471132  0.94248845  1.          0.92322179  0.869944    0.77425692
#   0.51425884  0.38674722  0.28476122  0.28880789  0.29531227  0.33378327
#   0.35381792  0.51620988  0.55200533  0.57373288  0.55522038  0.54988373
#   0.60414908  0.63131352  0.6269066   0.57159311  0.62411618  0.66482028
#   0.7003884   0.59946435  0.6025346   0.62895062  0.59937885  0.66180359
#   0.66828346  0.68919705  0.75162763  0.79245722  0.85722792  0.88820195
#   0.93297852  0.88476688  0.86109779  0.88482155  0.8744049   0.8034191
#   0.84431155  0.84987918  0.83148506  0.85252988  0.91639069  0.9175343
#   0.89957387  0.79786774  0.77184708  0.81669462  0.87284713  0.86058694
#   0.8392823   0.85396588  0.853277    0.87828277  0.85482593  0.84698544
#   0.80099242  0.78852797  0.79968192  0.83338407  0.86972013  0.83734191
#   0.84010373  0.84506835  0.85149396  0.82563394  0.84145091  0.8337395
#   0.83557277  0.84343721  0.86041657  0.82335063  0.80608402  0.75108857
#   0.68875124  0.55978538  0.43099215  0.3807537   0.486911    0.4057884
#   0.52836615  0.51659937  0.49712865  0.37128995  0.39457344  0.32253628
#   0.3380469   0.27089325  0.15633837  0.1113047   0.13350939  0.19486695
#   0.31936188  0.33971872  0.33959027  0.23936972  0.30474274  0.33157569
#   0.32161204  0.3496587   0.42528954  0.41258441  0.41132283  0.37882383
#   0.36539557  0.34763232  0.31657127  0.37664572  0.37336456  0.43332555
#   0.47445068  0.4969279   0.52922566  0.54969891  0.51873735  0.56087614
#   0.60389443  0.62411618  0.63915403  0.59603554  0.62271638  0.6649746
#   0.60643633  0.44617203  0.39043513  0.47983536  0.5211582   0.54356962
#   0.58344937  0.50609767  0.52616435  0.51279163  0.46460001  0.4682856
#   0.46248436  0.48537947  0.52086818  0.44016529  0.35029063 -0.15913656
#  -0.09181288  0.12205218  0.21936994  0.25187188  0.28040691  0.21626063
#   0.15941232  0.31216122  0.36625856  0.41464344  0.52212398  0.49662665
#   0.53284199  0.55218949  0.60355475  0.61366749  0.5851128   0.63172003
#   0.6776547   0.56359491  0.62567703  0.72732727  0.79233085  0.83462723
#   0.84302877  0.91732652  0.87418259  0.84692743  0.76324102  0.7041724
#   0.75216624]
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\tatuh\OneDrive\Asiakirjat\Aalto TKK\Master's Thesis\Modelling\brent_monthly_lstm2 test.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> # evaluate
#       <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> #mae, y, yhat = walk_forward_validation(data_new, len(test))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> mae, y, yhat = walk_forward_validation(data_new, 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> print('MAE: %.3f' % mae)
#
# c:\Users\tatuh\OneDrive\Asiakirjat\Aalto TKK\Master's Thesis\Modelling\brent_monthly_lstm2 test.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> testX, testy = test1[i, :-1], test1[i, -1]
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> # fit model on history and make a prediction
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> yhat = lstm_forecast(history, testX)
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=13'>14</a> # store forecast in list of predictions
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=14'>15</a> predictions.append(yhat)
#
# c:\Users\tatuh\OneDrive\Asiakirjat\Aalto TKK\Master's Thesis\Modelling\brent_monthly_lstm2 test.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=20'>21</a> model.add(Dense(1))
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=21'>22</a> model.compile(loss='mean_squared_error', optimizer='adam')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=22'>23</a> model.fit(trainX, trainy, epochs=100, batch_size=1, verbose=2)
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=23'>24</a> #model.fit(trainX, trainy, epochs=1, batch_size=1, verbose=2)
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=24'>25</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=25'>26</a>  # make a one-step prediction
#      <a href='vscode-notebook-cell:/c%3A/Users/tatuh/OneDrive/Asiakirjat/Aalto%20TKK/Master%27s%20Thesis/Modelling/brent_monthly_lstm2%20test.ipynb#X13sZmlsZQ%3D%3D?line=26'>27</a> yhat = model.predict([testX])
#
# File c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_fileio2mcpg9.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "c:\Users\tatuh\anaconda3\envs\tf\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_12" is incompatible with the layer: expected shape=(None, 3, 1), found shape=(1, 1, 3)

# %%
data_new.shape[1]
# Out:
# 13

# %%
y1 = scaler1.inverse_transform(y.reshape(-1, 1))
yhat1 = scaler1.inverse_transform(yhat)
#data_new1 = scaler1.inverse_transform(data_new)

# %%
#yhat1

# %%
# plot expected vs predicted
pyplot.plot(y1, label='Expected')
pyplot.plot(yhat1, label='Predicted')
pyplot.legend()
pyplot.show()

# %%
def smape_kun(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))*100

# %%
predictions = yhat1

# %%
exp_predictions = np.exp(predictions)
exp_spot= np.exp(spot)
exp_test = np.exp(test)
exp_train = np.exp(train)

x_axis = np.arange(exp_spot.shape[0])
n_test = exp_predictions.shape[0]

plt.plot(x_axis, exp_spot, alpha=0.75, c='b')
plt.plot(x_axis[-n_test:], exp_predictions, alpha=0.75, c='g')  # Forecasts
plt.title("Cross-validated forecasts")
plt.show()

# %%
error = mean_squared_error(exp_test, exp_predictions)
print('Mean Squared Error: %.3f' % error)
error2 = mean_absolute_error(exp_test, exp_predictions)
print('Mean Absolute Error: %.3f' % error2)
error3 = mean_absolute_percentage_error(exp_test, exp_predictions)
print('Mean Absolute Percentage Error: %.3f' % (error3*100))
error4 = smape_kun(exp_test, exp_predictions)
print('Symmetric Mean Absolute Percentage Error: %.3f' % error4)
# Out:
# Mean Squared Error: 47.511
# Mean Absolute Error: 5.079
# Mean Absolute Percentage Error: 8.678
# Symmetric Mean Absolute Percentage Error: 32.267

# %%
### same with built-in function ###

#predictions22 = model_selection.cross_val_score(
#    ar, spot, scoring='mean_absolute_error', cv=cv, verbose=0)
#np.average(predictions22)

# %%
#### MASE ###

abs_errors = abs(exp_predictions - exp_test)
mae_naive_list = []

for x in range(len(exp_test)):
    insample_data = exp_spot[x:-(len(exp_test)-x)]
    mae_insample = np.mean(abs(insample_data.diff().dropna()))
    mae_naive_list.append(mae_insample)

mase = np.mean(abs_errors / mae_naive_list)

print('Mean Absolute Scaled Error: %.3f' % mase)
# Out:
# Mean Absolute Scaled Error: 4.229

# %%
### Returns ###

returns = []

test_app2 = list(exp_test)
test_app2.insert(0, exp_train[-1]) ## append last of train data
price_moves = np.array(pd.DataFrame(test_app2).pct_change().dropna()+1)

pred_app2 = list(predictions)

test_shift2 = list(test)
test_shift2.insert(0, train[-1])
test_shift2.pop()

dir_pred2 = np.array(np.sign([a - b for a, b in zip(pred_app2,test_shift2)]))

for t in range(len(dir_pred2)):
    if dir_pred2[t] == 1:
            returns.append(price_moves[t])
        
    if dir_pred2[t] == -1:
        returns.append(1/price_moves[t])

returns = pd.DataFrame(returns)
returns
# Out:
#            0
# 0   1.107866
# 1   1.042942
# 2   0.984509
# 3   1.044928
# 4   1.125817
# ..       ...
# 71  1.043632
# 72  1.140118
# 73  0.911597
# 74  1.078104
# 75  0.900875
#
# [76 rows x 1 columns]

# %%
### Returns t-test ###

t_statistic, p_value = stats.ttest_1samp(a=returns, popmean=1, alternative='greater') ### one tailed test?


print(t_statistic , p_value)
# Out:
# [2.60119503] [0.00559318]

# %%
### Merton test ###

test_app = list(test)
test_app.insert(0, train[-1]) ## append last of train data
dir = np.array(np.sign(pd.DataFrame(test_app).diff().dropna()))

pred_app = list(predictions)

test_shift = list(test)
test_shift.insert(0, train[-1])
test_shift.pop()

dir_pred = np.array(np.sign([a - b for a, b in zip(pred_app,test_shift)]))

q_minus = 0
q_plus = 0
pred_minus = 0
pred_plus = 0

for t in range(len(dir)):
    if dir[t] == 1:
        q_plus += 1
        if dir_pred[t] == 1:
            pred_plus += 1
    if dir[t] == -1:
        q_minus += 1
        if dir_pred[t] == -1:
            pred_minus += 1

print('Merton test: %.3f' % ((pred_plus / q_plus) + (pred_minus / q_minus)))
# Out:
# Merton test: 1.328

# %%
len(test)
# Out:
# 76
