# %%
# Start loading libraries

#! pip install yfinance

# ! conda install seaborn

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import scipy
import scipy.stats as stats
import statsmodels.api as sm

import scipy
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

import pmdarima as pm
from pmdarima import model_selection
from pmdarima.model_selection import SlidingWindowForecastCV

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


from scipy.optimize import minimize
from random import gauss
import math
from statistics import mean, stdev

from numpy import asarray
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot


#! pip install tensorflow --user
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.layers import Input
from sklearn.preprocessing import MinMaxScaler

#from statsmodels.graphics.tsaplots import plot_acf

#from matplotlib.ticker import NullFormatter
#import yfinance as yf
#import warnings; warnings.simplefilter('ignore')
#%matplotlib inline

# %%
xls_file = pd.ExcelFile("Data_monthly_final.xlsx") # Read Excel
df1=xls_file.parse("Brent") # Read the first sheet (Portfolio holdings)

#df1["Timestamp"] = df1["Date"].astype('datetime64[ns]') # Convert column to date format
df1 = df1.set_index(['Timestamp']) # use first column as index

#df1.to_excel("values.xlsx")  #print to excel

# %%
spot = df1["LCOc1"]
spot = np.log(spot)
spot = spot.loc['2004-01-31':'2022-11-30']
spot_train = spot.loc[:'2016-07-31']
#spot_train.plot()

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
 #n_vars = 1 if type(data) is list else data.shape[1]
 df_temp = pd.DataFrame(data)
 cols = list()
 # input sequence (t-n, ... t-1)
 for i in range(n_in, 0, -1):
    cols.append(df_temp.shift(i))
 # forecast sequence (t, t+1, ... t+n)
 for i in range(0, n_out):
    cols.append(df_temp.shift(-i))
 # put it all together
 agg = pd.concat(cols, axis=1)
 # drop rows with NaN values
 if dropnan:
    agg.dropna(inplace=True)
 return agg.values

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# Load the data and split it into separate pieces
data = np.array(spot.dropna())
train, test = model_selection.train_test_split(data, train_size=(spot_train.shape[0]))

# normalize the dataset
scaler1 = MinMaxScaler(feature_range=(0, 1)).fit(train.reshape(-1, 1))  ### using only train data in the scaling
data_scaled = scaler1.transform(data.reshape(-1, 1))

time_lag = 12

batch_size = 1
epochs = 100

data_new = series_to_supervised(data_scaled, n_in=time_lag, n_out=1, dropnan=True)
#train, test = model_selection.train_test_split(data, train_size=(spot.shape[0]-1))

# %%
#data_scaled1 = scaler1.inverse_transform(data_scaled)
#np.exp(data_scaled1)

# %%
#train_new  = series_to_supervised(train, n_in=time_lag, n_out=1, dropnan=True)
#test_new = series_to_supervised(test, n_in=time_lag, n_out=1, dropnan=True)

# %%
# fit an lstm model and make a one step prediction
def lstm_forecast(trainlocal, testX):
 # transform list into array
 trainlocalar = asarray(trainlocal)
 # split into input and output columns
 trainX, trainy = trainlocalar[:, :-1], trainlocalar[:, -1]

 # reshape input to be [samples, time steps, features]
 trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
 testX = np.reshape(testX, (1, testX.shape[0], 1))  ### batch size 1 because model is recalibrated after avery step
 #testX = np.reshape(testX, (testX.shape[0], trainX.shape[1], 1))     #### PURKKARATKAISU ###

 # create and fit the LSTM network
 model = Sequential()
 #model.add(InputLayer((time_lag,1)))
 model.add(InputLayer((time_lag,1)))
 model.add(LSTM(150))
 #model.add(LSTM(4))
 #model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
 model.add(Dense(1))
 model.compile(loss='mean_squared_error', optimizer='adam')
 model.fit(trainX, trainy, epochs=epochs, batch_size=batch_size, verbose=2, shuffle=False)
 #model.fit(trainX, trainy, epochs=1, batch_size=1, verbose=2)
 
  # make a one-step prediction
 yhat = model.predict(testX)
 return yhat[0]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
   predictions = list()
   # split dataset
   train1, test1 = train_test_split(data, n_test)
   # seed history with training dataset
   history = [x for x in train1]
   # step over each time-step in the test set
   for i in range(len(test1)):
      # split test row into input and output columns
      testX, testy = test1[i, :-1], test1[i, -1]
      # fit model on history and make a prediction
      yhat = lstm_forecast(history, testX)
      # store forecast in list of predictions
      predictions.append(yhat)
      # add actual observation to history for the next loop and delete oldest one
      history.append(test1[i])
      history.pop(0)
      # summarize progress
      print('>expected=%.1f, predicted=%.1f' % (testy, yhat))

    # estimate prediction error
   error = mean_absolute_error(test1[:, -1], predictions)
   return error, test1[:, -1], predictions

# %%
# evaluate
mae, y, yhat = walk_forward_validation(data_new, len(test))
#mae, y, yhat = walk_forward_validation(data_new, 2)
print('MAE: %.3f' % mae)
# Out:
# Epoch 1/100
# 139/139 - 2s - loss: 0.0274 - 2s/epoch - 12ms/step
# Epoch 2/100
# 139/139 - 0s - loss: 0.0226 - 466ms/epoch - 3ms/step
# Epoch 3/100
# 139/139 - 0s - loss: 0.0240 - 472ms/epoch - 3ms/step
# Epoch 4/100
# 139/139 - 0s - loss: 0.0234 - 480ms/epoch - 3ms/step
# Epoch 5/100
# 139/139 - 0s - loss: 0.0206 - 472ms/epoch - 3ms/step
# Epoch 6/100
# 139/139 - 0s - loss: 0.0176 - 472ms/epoch - 3ms/step
# Epoch 7/100
# 139/139 - 0s - loss: 0.0156 - 466ms/epoch - 3ms/step
# Epoch 8/100
# 139/139 - 0s - loss: 0.0136 - 438ms/epoch - 3ms/step
# Epoch 9/100
# 139/139 - 0s - loss: 0.0120 - 451ms/epoch - 3ms/step
# Epoch 10/100
# 139/139 - 0s - loss: 0.0107 - 458ms/epoch - 3ms/step
# Epoch 11/100
# 139/139 - 0s - loss: 0.0094 - 450ms/epoch - 3ms/step
# Epoch 12/100
# 139/139 - 0s - loss: 0.0085 - 483ms/epoch - 3ms/step
# Epoch 13/100
# 139/139 - 0s - loss: 0.0076 - 434ms/epoch - 3ms/step
# Epoch 14/100
# 139/139 - 0s - loss: 0.0069 - 456ms/epoch - 3ms/step
# Epoch 15/100
# 139/139 - 0s - loss: 0.0063 - 434ms/epoch - 3ms/step
# Epoch 16/100
# 139/139 - 0s - loss: 0.0058 - 431ms/epoch - 3ms/step
# Epoch 17/100
# 139/139 - 0s - loss: 0.0053 - 441ms/epoch - 3ms/step
# Epoch 18/100
# 139/139 - 0s - loss: 0.0049 - 446ms/epoch - 3ms/step
# Epoch 19/100
# 139/139 - 0s - loss: 0.0046 - 473ms/epoch - 3ms/step
# Epoch 20/100
# 139/139 - 0s - loss: 0.0043 - 473ms/epoch - 3ms/step
# Epoch 21/100
# 139/139 - 0s - loss: 0.0042 - 464ms/epoch - 3ms/step
# Epoch 22/100
# 139/139 - 0s - loss: 0.0041 - 475ms/epoch - 3ms/step
# Epoch 23/100
# 139/139 - 0s - loss: 0.0041 - 487ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 0s - loss: 0.0040 - 487ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 0s - loss: 0.0040 - 436ms/epoch - 3ms/step
# Epoch 26/100
# 139/139 - 0s - loss: 0.0040 - 440ms/epoch - 3ms/step
# Epoch 27/100
# 139/139 - 0s - loss: 0.0040 - 481ms/epoch - 3ms/step
# Epoch 28/100
# 139/139 - 0s - loss: 0.0040 - 430ms/epoch - 3ms/step
# Epoch 29/100
# 139/139 - 0s - loss: 0.0040 - 440ms/epoch - 3ms/step
# Epoch 30/100
# 139/139 - 0s - loss: 0.0039 - 446ms/epoch - 3ms/step
# Epoch 31/100
# 139/139 - 0s - loss: 0.0039 - 444ms/epoch - 3ms/step
# Epoch 32/100
# 139/139 - 0s - loss: 0.0039 - 436ms/epoch - 3ms/step
# Epoch 33/100
# 139/139 - 0s - loss: 0.0039 - 440ms/epoch - 3ms/step
# Epoch 34/100
# 139/139 - 0s - loss: 0.0039 - 438ms/epoch - 3ms/step
# Epoch 35/100
# 139/139 - 0s - loss: 0.0039 - 439ms/epoch - 3ms/step
# Epoch 36/100
# 139/139 - 0s - loss: 0.0039 - 436ms/epoch - 3ms/step
# Epoch 37/100
# 139/139 - 0s - loss: 0.0039 - 432ms/epoch - 3ms/step
# Epoch 38/100
# 139/139 - 0s - loss: 0.0039 - 440ms/epoch - 3ms/step
# Epoch 39/100
# 139/139 - 0s - loss: 0.0039 - 438ms/epoch - 3ms/step
# Epoch 40/100
# 139/139 - 0s - loss: 0.0039 - 439ms/epoch - 3ms/step
# Epoch 41/100
# 139/139 - 0s - loss: 0.0039 - 430ms/epoch - 3ms/step
# Epoch 42/100
# 139/139 - 0s - loss: 0.0039 - 438ms/epoch - 3ms/step
# Epoch 43/100
# 139/139 - 0s - loss: 0.0039 - 446ms/epoch - 3ms/step
# Epoch 44/100
# 139/139 - 0s - loss: 0.0040 - 441ms/epoch - 3ms/step
# Epoch 45/100
# 139/139 - 0s - loss: 0.0039 - 431ms/epoch - 3ms/step
# Epoch 46/100
# 139/139 - 0s - loss: 0.0037 - 438ms/epoch - 3ms/step
# Epoch 47/100
# 139/139 - 0s - loss: 0.0037 - 446ms/epoch - 3ms/step
# Epoch 48/100
# 139/139 - 0s - loss: 0.0037 - 445ms/epoch - 3ms/step
# Epoch 49/100
# 139/139 - 0s - loss: 0.0037 - 437ms/epoch - 3ms/step
# Epoch 50/100
# 139/139 - 0s - loss: 0.0037 - 436ms/epoch - 3ms/step
# Epoch 51/100
# 139/139 - 0s - loss: 0.0037 - 439ms/epoch - 3ms/step
# Epoch 52/100
# 139/139 - 0s - loss: 0.0037 - 466ms/epoch - 3ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0037 - 528ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0037 - 518ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 0s - loss: 0.0036 - 486ms/epoch - 3ms/step
# Epoch 56/100
# 139/139 - 0s - loss: 0.0032 - 467ms/epoch - 3ms/step
# Epoch 57/100
# 139/139 - 0s - loss: 0.0038 - 474ms/epoch - 3ms/step
# Epoch 58/100
# 139/139 - 0s - loss: 0.0036 - 479ms/epoch - 3ms/step
# Epoch 59/100
# 139/139 - 0s - loss: 0.0035 - 472ms/epoch - 3ms/step
# Epoch 60/100
# 139/139 - 0s - loss: 0.0035 - 467ms/epoch - 3ms/step
# Epoch 61/100
# 139/139 - 0s - loss: 0.0034 - 470ms/epoch - 3ms/step
# Epoch 62/100
# 139/139 - 0s - loss: 0.0035 - 447ms/epoch - 3ms/step
# Epoch 63/100
# 139/139 - 0s - loss: 0.0035 - 452ms/epoch - 3ms/step
# Epoch 64/100
# 139/139 - 0s - loss: 0.0035 - 427ms/epoch - 3ms/step
# Epoch 65/100
# 139/139 - 0s - loss: 0.0034 - 463ms/epoch - 3ms/step
# Epoch 66/100
# 139/139 - 0s - loss: 0.0034 - 428ms/epoch - 3ms/step
# Epoch 67/100
# 139/139 - 0s - loss: 0.0034 - 433ms/epoch - 3ms/step
# Epoch 68/100
# 139/139 - 0s - loss: 0.0034 - 492ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0034 - 505ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 0s - loss: 0.0033 - 434ms/epoch - 3ms/step
# Epoch 71/100
# 139/139 - 0s - loss: 0.0033 - 431ms/epoch - 3ms/step
# Epoch 72/100
# 139/139 - 0s - loss: 0.0033 - 451ms/epoch - 3ms/step
# Epoch 73/100
# 139/139 - 0s - loss: 0.0033 - 461ms/epoch - 3ms/step
# Epoch 74/100
# 139/139 - 0s - loss: 0.0033 - 447ms/epoch - 3ms/step
# Epoch 75/100
# 139/139 - 0s - loss: 0.0032 - 447ms/epoch - 3ms/step
# Epoch 76/100
# 139/139 - 0s - loss: 0.0032 - 444ms/epoch - 3ms/step
# Epoch 77/100
# 139/139 - 0s - loss: 0.0032 - 463ms/epoch - 3ms/step
# Epoch 78/100
# 139/139 - 0s - loss: 0.0033 - 433ms/epoch - 3ms/step
# Epoch 79/100
# 139/139 - 0s - loss: 0.0032 - 446ms/epoch - 3ms/step
# Epoch 80/100
# 139/139 - 0s - loss: 0.0033 - 491ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0034 - 509ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0033 - 530ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 0s - loss: 0.0032 - 489ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0032 - 550ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0032 - 582ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0031 - 598ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0032 - 617ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0031 - 630ms/epoch - 5ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0031 - 613ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0031 - 594ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0031 - 605ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 647ms/epoch - 5ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0031 - 665ms/epoch - 5ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0031 - 690ms/epoch - 5ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0031 - 666ms/epoch - 5ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0031 - 582ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0031 - 542ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0032 - 563ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0030 - 616ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0030 - 643ms/epoch - 5ms/step
# 1/1 [==============================] - 1s 586ms/step
# >expected=0.3, predicted=0.2
# C:\Users\tatuh\AppData\Local\Temp\ipykernel_12068\3682001088.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
# Epoch 1/100
# 139/139 - 3s - loss: 0.0244 - 3s/epoch - 20ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0221 - 592ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0233 - 598ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0237 - 571ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0197 - 579ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0174 - 575ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0148 - 579ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0130 - 587ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0115 - 596ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0103 - 609ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0091 - 582ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0082 - 605ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0073 - 583ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0068 - 586ms/epoch - 4ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0062 - 583ms/epoch - 4ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0057 - 596ms/epoch - 4ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0053 - 583ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0048 - 569ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0045 - 573ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0043 - 635ms/epoch - 5ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0042 - 648ms/epoch - 5ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0041 - 662ms/epoch - 5ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0041 - 656ms/epoch - 5ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0041 - 572ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0041 - 561ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0041 - 605ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0041 - 580ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0041 - 572ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0041 - 589ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0040 - 578ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0040 - 558ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0040 - 572ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0040 - 569ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0040 - 571ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0040 - 581ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0040 - 588ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0040 - 587ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0040 - 567ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0040 - 577ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0040 - 586ms/epoch - 4ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0040 - 575ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0039 - 575ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0039 - 570ms/epoch - 4ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0038 - 576ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0036 - 570ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0035 - 588ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0034 - 576ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0043 - 582ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0038 - 575ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0037 - 588ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0036 - 580ms/epoch - 4ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0036 - 574ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0035 - 571ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0035 - 580ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0035 - 588ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0035 - 583ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0035 - 576ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0035 - 563ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0035 - 568ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0034 - 585ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0034 - 593ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0034 - 580ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0034 - 570ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0034 - 582ms/epoch - 4ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0034 - 575ms/epoch - 4ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0034 - 621ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0033 - 596ms/epoch - 4ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0033 - 573ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0033 - 591ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0033 - 586ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0033 - 589ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0033 - 556ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0032 - 571ms/epoch - 4ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0032 - 567ms/epoch - 4ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0032 - 577ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0033 - 573ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0032 - 573ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0033 - 578ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0036 - 567ms/epoch - 4ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0032 - 561ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0033 - 574ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0033 - 584ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0033 - 580ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0032 - 589ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0032 - 581ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0032 - 564ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0032 - 615ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0031 - 567ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0031 - 559ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0031 - 552ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 0s - loss: 0.0031 - 499ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 507ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 0s - loss: 0.0030 - 499ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 0s - loss: 0.0032 - 494ms/epoch - 4ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0031 - 526ms/epoch - 4ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0031 - 588ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0031 - 595ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0030 - 595ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0030 - 601ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0030 - 590ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 430ms/step
# >expected=0.3, predicted=0.3
# Epoch 1/100
# 139/139 - 2s - loss: 0.0306 - 2s/epoch - 15ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0249 - 619ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0259 - 580ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0226 - 574ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0195 - 571ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0173 - 576ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0150 - 589ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0133 - 591ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0118 - 606ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0103 - 572ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0092 - 564ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0082 - 563ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0075 - 568ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0068 - 573ms/epoch - 4ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0062 - 573ms/epoch - 4ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0057 - 572ms/epoch - 4ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0052 - 560ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0049 - 562ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0045 - 574ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0043 - 568ms/epoch - 4ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0042 - 579ms/epoch - 4ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0041 - 578ms/epoch - 4ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0041 - 572ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0041 - 561ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0040 - 573ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0041 - 559ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0041 - 550ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0041 - 521ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0040 - 546ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0040 - 584ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0039 - 565ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0039 - 578ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0039 - 570ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0039 - 581ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0040 - 575ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0039 - 578ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0039 - 592ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0039 - 568ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0039 - 570ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0039 - 576ms/epoch - 4ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0039 - 583ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0040 - 608ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0039 - 652ms/epoch - 5ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0037 - 600ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0037 - 573ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0037 - 579ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0038 - 571ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0038 - 592ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0036 - 589ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0035 - 591ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0039 - 648ms/epoch - 5ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0036 - 598ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0038 - 570ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0032 - 568ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0036 - 578ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0036 - 587ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0034 - 582ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0034 - 578ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0034 - 586ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0034 - 588ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0034 - 586ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0034 - 572ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0034 - 583ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0034 - 587ms/epoch - 4ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0034 - 579ms/epoch - 4ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0034 - 607ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0034 - 584ms/epoch - 4ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0034 - 601ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0034 - 583ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0034 - 591ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0034 - 583ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0033 - 583ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0033 - 579ms/epoch - 4ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0033 - 577ms/epoch - 4ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0033 - 583ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0033 - 582ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0033 - 578ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0033 - 584ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0032 - 574ms/epoch - 4ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0032 - 588ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0032 - 582ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0035 - 574ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0032 - 574ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0034 - 582ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0038 - 602ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0035 - 583ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0035 - 572ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0034 - 583ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0034 - 585ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0033 - 580ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0033 - 584ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0033 - 572ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0033 - 571ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0033 - 571ms/epoch - 4ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0033 - 574ms/epoch - 4ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0032 - 591ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0032 - 593ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0031 - 590ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0031 - 581ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0031 - 600ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 424ms/step
# >expected=0.3, predicted=0.4
# Epoch 1/100
# 139/139 - 2s - loss: 0.0305 - 2s/epoch - 16ms/step
# Epoch 2/100
# 139/139 - 0s - loss: 0.0229 - 495ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 0s - loss: 0.0253 - 492ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 0s - loss: 0.0235 - 494ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0205 - 501ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0181 - 607ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0160 - 594ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0140 - 612ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0125 - 610ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0109 - 580ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0099 - 566ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0086 - 580ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0079 - 575ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0069 - 593ms/epoch - 4ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0065 - 579ms/epoch - 4ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0058 - 571ms/epoch - 4ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0054 - 572ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0049 - 571ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0046 - 583ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0044 - 576ms/epoch - 4ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0043 - 571ms/epoch - 4ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0042 - 589ms/epoch - 4ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0041 - 578ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0041 - 588ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0041 - 585ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0041 - 591ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0041 - 592ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0040 - 583ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0040 - 584ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0039 - 573ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0039 - 587ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0039 - 585ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0039 - 582ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0039 - 603ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0039 - 597ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0039 - 587ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0039 - 576ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0039 - 585ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0039 - 592ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0039 - 580ms/epoch - 4ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0039 - 598ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0039 - 601ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0039 - 586ms/epoch - 4ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0039 - 583ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0038 - 574ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0038 - 594ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0037 - 587ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0037 - 596ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0036 - 588ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0036 - 581ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0036 - 576ms/epoch - 4ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0036 - 580ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0036 - 591ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0035 - 590ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0035 - 569ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0035 - 572ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0034 - 571ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0034 - 571ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0034 - 600ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0034 - 586ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0034 - 601ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0035 - 588ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0035 - 583ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0035 - 636ms/epoch - 5ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0034 - 673ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0034 - 589ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0035 - 632ms/epoch - 5ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0034 - 582ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0033 - 608ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0031 - 623ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0033 - 620ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0032 - 608ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0032 - 645ms/epoch - 5ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0032 - 645ms/epoch - 5ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0032 - 589ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0033 - 582ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0032 - 564ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0032 - 580ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0031 - 629ms/epoch - 5ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0031 - 582ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0031 - 568ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0031 - 567ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0032 - 559ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0032 - 567ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0032 - 577ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0031 - 578ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0032 - 577ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0032 - 570ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0032 - 574ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0031 - 573ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0031 - 568ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 569ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0031 - 563ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0031 - 561ms/epoch - 4ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0031 - 555ms/epoch - 4ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0030 - 556ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0030 - 547ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0030 - 565ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0031 - 567ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0032 - 555ms/epoch - 4ms/step
# 1/1 [==============================] - 0s 421ms/step
# >expected=0.3, predicted=0.3
# Epoch 1/100
# 139/139 - 2s - loss: 0.0315 - 2s/epoch - 16ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0200 - 580ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0240 - 565ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0242 - 558ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0217 - 545ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0178 - 606ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0157 - 569ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0137 - 576ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0123 - 563ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0107 - 554ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0097 - 616ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0085 - 560ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0078 - 551ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 0s - loss: 0.0069 - 475ms/epoch - 3ms/step
# Epoch 15/100
# 139/139 - 0s - loss: 0.0063 - 475ms/epoch - 3ms/step
# Epoch 16/100
# 139/139 - 0s - loss: 0.0057 - 477ms/epoch - 3ms/step
# Epoch 17/100
# 139/139 - 0s - loss: 0.0051 - 487ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0048 - 515ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0045 - 555ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0044 - 559ms/epoch - 4ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0043 - 562ms/epoch - 4ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0042 - 566ms/epoch - 4ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0041 - 549ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0041 - 563ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0041 - 557ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0041 - 550ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0040 - 558ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0040 - 557ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0039 - 552ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0039 - 571ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0039 - 561ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0039 - 559ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0039 - 550ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0039 - 566ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0039 - 553ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0038 - 562ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0039 - 568ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0038 - 563ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0036 - 570ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0037 - 566ms/epoch - 4ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0036 - 570ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0035 - 566ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0042 - 562ms/epoch - 4ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0040 - 567ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0037 - 559ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0037 - 562ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0036 - 551ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0036 - 579ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0036 - 558ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0036 - 561ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0036 - 557ms/epoch - 4ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0036 - 545ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0036 - 555ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0036 - 551ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0036 - 555ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0036 - 550ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0036 - 557ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0036 - 558ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0036 - 570ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0035 - 579ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0036 - 552ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0036 - 574ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0035 - 562ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0035 - 554ms/epoch - 4ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0035 - 554ms/epoch - 4ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0035 - 575ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0035 - 571ms/epoch - 4ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0035 - 556ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0035 - 576ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0035 - 560ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0035 - 566ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0035 - 562ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0035 - 559ms/epoch - 4ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0035 - 560ms/epoch - 4ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0034 - 569ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0034 - 540ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0034 - 566ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0034 - 569ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0034 - 559ms/epoch - 4ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0035 - 559ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0038 - 555ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0035 - 552ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0032 - 558ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0033 - 559ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0033 - 548ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0033 - 550ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0032 - 565ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0032 - 569ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0032 - 549ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0032 - 572ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0031 - 553ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 553ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0034 - 561ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0034 - 554ms/epoch - 4ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0032 - 574ms/epoch - 4ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0031 - 556ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0030 - 565ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0030 - 558ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0030 - 556ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0030 - 560ms/epoch - 4ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DE14809CA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 420ms/step
# >expected=0.4, predicted=0.3
# Epoch 1/100
# 139/139 - 3s - loss: 0.0280 - 3s/epoch - 18ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0190 - 607ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0218 - 595ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0210 - 598ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0187 - 601ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0164 - 600ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0142 - 597ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0124 - 588ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0111 - 593ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0098 - 616ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0088 - 592ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0080 - 625ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0075 - 589ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0067 - 595ms/epoch - 4ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0061 - 588ms/epoch - 4ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0054 - 600ms/epoch - 4ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0050 - 599ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0046 - 592ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0044 - 595ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0043 - 592ms/epoch - 4ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0043 - 595ms/epoch - 4ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0042 - 598ms/epoch - 4ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0042 - 598ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0042 - 582ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0043 - 501ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 0s - loss: 0.0043 - 497ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0042 - 515ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0041 - 509ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0041 - 532ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0041 - 593ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0040 - 597ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0040 - 589ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0040 - 605ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0040 - 598ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0040 - 595ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0040 - 604ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0040 - 596ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0040 - 594ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0040 - 594ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0040 - 592ms/epoch - 4ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0040 - 586ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0040 - 590ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0040 - 592ms/epoch - 4ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0041 - 590ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0040 - 594ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0038 - 584ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0038 - 588ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0038 - 581ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0038 - 583ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0038 - 594ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0038 - 597ms/epoch - 4ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0038 - 593ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0035 - 601ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0036 - 579ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0038 - 583ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0036 - 593ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0036 - 597ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0037 - 597ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0035 - 591ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0035 - 580ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0035 - 591ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0035 - 617ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0035 - 603ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0035 - 592ms/epoch - 4ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0035 - 633ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0035 - 599ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0035 - 605ms/epoch - 4ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0035 - 590ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0035 - 611ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0035 - 584ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0035 - 599ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0035 - 592ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0035 - 596ms/epoch - 4ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0034 - 582ms/epoch - 4ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0034 - 593ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0034 - 589ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0034 - 590ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0034 - 585ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0033 - 594ms/epoch - 4ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0033 - 583ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0032 - 586ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0033 - 581ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0033 - 603ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0034 - 592ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0034 - 586ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0033 - 586ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0032 - 586ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0032 - 591ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0032 - 594ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0032 - 591ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0032 - 596ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 595ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0031 - 585ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0033 - 593ms/epoch - 4ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0032 - 582ms/epoch - 4ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0032 - 585ms/epoch - 4ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0033 - 595ms/epoch - 4ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0030 - 595ms/epoch - 4ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0031 - 605ms/epoch - 4ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0031 - 608ms/epoch - 4ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001DE17BD7AF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 430ms/step
# >expected=0.4, predicted=0.5
# Epoch 1/100
# 139/139 - 2s - loss: 0.0410 - 2s/epoch - 15ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0274 - 571ms/epoch - 4ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0286 - 570ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0244 - 556ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0204 - 558ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0182 - 588ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0164 - 571ms/epoch - 4ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0143 - 569ms/epoch - 4ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0126 - 588ms/epoch - 4ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0110 - 563ms/epoch - 4ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0100 - 565ms/epoch - 4ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0087 - 574ms/epoch - 4ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0080 - 567ms/epoch - 4ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0070 - 562ms/epoch - 4ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0064 - 568ms/epoch - 4ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0057 - 569ms/epoch - 4ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0052 - 561ms/epoch - 4ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0049 - 570ms/epoch - 4ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0046 - 575ms/epoch - 4ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0045 - 576ms/epoch - 4ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0044 - 642ms/epoch - 5ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0043 - 579ms/epoch - 4ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0042 - 577ms/epoch - 4ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0042 - 565ms/epoch - 4ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0041 - 571ms/epoch - 4ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0041 - 578ms/epoch - 4ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0041 - 572ms/epoch - 4ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0040 - 557ms/epoch - 4ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0040 - 566ms/epoch - 4ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0039 - 574ms/epoch - 4ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0039 - 568ms/epoch - 4ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0039 - 573ms/epoch - 4ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0039 - 571ms/epoch - 4ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0040 - 569ms/epoch - 4ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0039 - 570ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0039 - 519ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 0s - loss: 0.0040 - 492ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 0s - loss: 0.0039 - 485ms/epoch - 3ms/step
# Epoch 39/100
# 139/139 - 0s - loss: 0.0039 - 490ms/epoch - 4ms/step
# Epoch 40/100
# 139/139 - 0s - loss: 0.0039 - 476ms/epoch - 3ms/step
# Epoch 41/100
# 139/139 - 0s - loss: 0.0038 - 490ms/epoch - 4ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0038 - 556ms/epoch - 4ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0039 - 579ms/epoch - 4ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0036 - 585ms/epoch - 4ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0035 - 585ms/epoch - 4ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0041 - 580ms/epoch - 4ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0037 - 569ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0037 - 575ms/epoch - 4ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0037 - 587ms/epoch - 4ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0037 - 597ms/epoch - 4ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0037 - 585ms/epoch - 4ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0037 - 577ms/epoch - 4ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0037 - 581ms/epoch - 4ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0037 - 574ms/epoch - 4ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0036 - 583ms/epoch - 4ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0036 - 568ms/epoch - 4ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0036 - 586ms/epoch - 4ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0036 - 606ms/epoch - 4ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0036 - 589ms/epoch - 4ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0036 - 571ms/epoch - 4ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0036 - 579ms/epoch - 4ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0036 - 596ms/epoch - 4ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0036 - 583ms/epoch - 4ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0036 - 585ms/epoch - 4ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0036 - 637ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0036 - 585ms/epoch - 4ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0036 - 590ms/epoch - 4ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0036 - 597ms/epoch - 4ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0035 - 583ms/epoch - 4ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0036 - 579ms/epoch - 4ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0035 - 590ms/epoch - 4ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0035 - 576ms/epoch - 4ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0035 - 573ms/epoch - 4ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0035 - 580ms/epoch - 4ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0035 - 570ms/epoch - 4ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0036 - 576ms/epoch - 4ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0035 - 590ms/epoch - 4ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0034 - 591ms/epoch - 4ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0033 - 586ms/epoch - 4ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0033 - 606ms/epoch - 4ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0034 - 569ms/epoch - 4ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0035 - 582ms/epoch - 4ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0035 - 582ms/epoch - 4ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0038 - 581ms/epoch - 4ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0034 - 589ms/epoch - 4ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0033 - 587ms/epoch - 4ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0033 - 584ms/epoch - 4ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0033 - 582ms/epoch - 4ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0032 - 584ms/epoch - 4ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0031 - 577ms/epoch - 4ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0031 - 570ms/epoch - 4ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0031 - 595ms/epoch - 4ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0031 - 578ms/epoch - 4ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0031 - 567ms/epoch - 4ms/step
# Epoch 95/100
# ...
# 139/139 - 1s - loss: 0.0047 - 735ms/epoch - 5ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0047 - 744ms/epoch - 5ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0046 - 748ms/epoch - 5ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0046 - 720ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0047 - 720ms/epoch - 5ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0050 - 732ms/epoch - 5ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0049 - 722ms/epoch - 5ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0045 - 733ms/epoch - 5ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0045 - 779ms/epoch - 6ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0045 - 759ms/epoch - 5ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0044 - 728ms/epoch - 5ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0043 - 735ms/epoch - 5ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0044 - 732ms/epoch - 5ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0044 - 743ms/epoch - 5ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0045 - 736ms/epoch - 5ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0047 - 725ms/epoch - 5ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0044 - 732ms/epoch - 5ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0043 - 724ms/epoch - 5ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0044 - 731ms/epoch - 5ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0043 - 727ms/epoch - 5ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0042 - 732ms/epoch - 5ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0045 - 714ms/epoch - 5ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0045 - 733ms/epoch - 5ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0043 - 734ms/epoch - 5ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0042 - 745ms/epoch - 5ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0044 - 734ms/epoch - 5ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0043 - 721ms/epoch - 5ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0048 - 725ms/epoch - 5ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0045 - 736ms/epoch - 5ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0042 - 748ms/epoch - 5ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0043 - 735ms/epoch - 5ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0042 - 730ms/epoch - 5ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0041 - 729ms/epoch - 5ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0041 - 745ms/epoch - 5ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0043 - 723ms/epoch - 5ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0044 - 729ms/epoch - 5ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0045 - 714ms/epoch - 5ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0041 - 745ms/epoch - 5ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0040 - 735ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 426ms/step
# >expected=0.7, predicted=0.7
# Epoch 1/100
# 139/139 - 2s - loss: 0.0372 - 2s/epoch - 16ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0219 - 634ms/epoch - 5ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0196 - 601ms/epoch - 4ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0178 - 590ms/epoch - 4ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0168 - 620ms/epoch - 4ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0157 - 618ms/epoch - 4ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0145 - 694ms/epoch - 5ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0127 - 700ms/epoch - 5ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0114 - 691ms/epoch - 5ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0114 - 695ms/epoch - 5ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0106 - 703ms/epoch - 5ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0086 - 686ms/epoch - 5ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0092 - 689ms/epoch - 5ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0076 - 688ms/epoch - 5ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0072 - 697ms/epoch - 5ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0066 - 694ms/epoch - 5ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0067 - 693ms/epoch - 5ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0061 - 699ms/epoch - 5ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0062 - 707ms/epoch - 5ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0059 - 685ms/epoch - 5ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0058 - 701ms/epoch - 5ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0060 - 700ms/epoch - 5ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0055 - 683ms/epoch - 5ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0057 - 715ms/epoch - 5ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0057 - 691ms/epoch - 5ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0057 - 692ms/epoch - 5ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0057 - 696ms/epoch - 5ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0058 - 681ms/epoch - 5ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0056 - 682ms/epoch - 5ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0054 - 705ms/epoch - 5ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0055 - 695ms/epoch - 5ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0055 - 687ms/epoch - 5ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0055 - 710ms/epoch - 5ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0054 - 708ms/epoch - 5ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0055 - 693ms/epoch - 5ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0055 - 679ms/epoch - 5ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0055 - 687ms/epoch - 5ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0055 - 712ms/epoch - 5ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0054 - 695ms/epoch - 5ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0053 - 716ms/epoch - 5ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0053 - 692ms/epoch - 5ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0053 - 693ms/epoch - 5ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0053 - 687ms/epoch - 5ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0052 - 697ms/epoch - 5ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0052 - 714ms/epoch - 5ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0052 - 691ms/epoch - 5ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0051 - 623ms/epoch - 4ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0051 - 686ms/epoch - 5ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0051 - 701ms/epoch - 5ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0050 - 684ms/epoch - 5ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0050 - 761ms/epoch - 5ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0050 - 727ms/epoch - 5ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0049 - 692ms/epoch - 5ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0049 - 702ms/epoch - 5ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0048 - 721ms/epoch - 5ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0048 - 700ms/epoch - 5ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0048 - 696ms/epoch - 5ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0047 - 688ms/epoch - 5ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0047 - 693ms/epoch - 5ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0047 - 720ms/epoch - 5ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0047 - 694ms/epoch - 5ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0047 - 693ms/epoch - 5ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0048 - 706ms/epoch - 5ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0046 - 712ms/epoch - 5ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0045 - 691ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0046 - 688ms/epoch - 5ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0045 - 703ms/epoch - 5ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0045 - 719ms/epoch - 5ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0046 - 690ms/epoch - 5ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0045 - 702ms/epoch - 5ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0045 - 709ms/epoch - 5ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0044 - 693ms/epoch - 5ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0044 - 688ms/epoch - 5ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0045 - 701ms/epoch - 5ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0044 - 689ms/epoch - 5ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0044 - 692ms/epoch - 5ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0044 - 706ms/epoch - 5ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0043 - 716ms/epoch - 5ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0043 - 685ms/epoch - 5ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0045 - 702ms/epoch - 5ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0044 - 699ms/epoch - 5ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0043 - 695ms/epoch - 5ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0043 - 721ms/epoch - 5ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0044 - 702ms/epoch - 5ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0043 - 709ms/epoch - 5ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0043 - 695ms/epoch - 5ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0043 - 701ms/epoch - 5ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0042 - 698ms/epoch - 5ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0043 - 698ms/epoch - 5ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0043 - 694ms/epoch - 5ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0045 - 713ms/epoch - 5ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0044 - 694ms/epoch - 5ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0042 - 687ms/epoch - 5ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0042 - 699ms/epoch - 5ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0044 - 687ms/epoch - 5ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0044 - 698ms/epoch - 5ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0044 - 697ms/epoch - 5ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0043 - 698ms/epoch - 5ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0041 - 702ms/epoch - 5ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0043 - 706ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 426ms/step
# >expected=0.8, predicted=0.6
# Epoch 1/100
# 139/139 - 3s - loss: 0.0385 - 3s/epoch - 19ms/step
# Epoch 2/100
# 139/139 - 1s - loss: 0.0224 - 698ms/epoch - 5ms/step
# Epoch 3/100
# 139/139 - 1s - loss: 0.0202 - 712ms/epoch - 5ms/step
# Epoch 4/100
# 139/139 - 1s - loss: 0.0191 - 696ms/epoch - 5ms/step
# Epoch 5/100
# 139/139 - 1s - loss: 0.0179 - 705ms/epoch - 5ms/step
# Epoch 6/100
# 139/139 - 1s - loss: 0.0166 - 710ms/epoch - 5ms/step
# Epoch 7/100
# 139/139 - 1s - loss: 0.0156 - 706ms/epoch - 5ms/step
# Epoch 8/100
# 139/139 - 1s - loss: 0.0139 - 709ms/epoch - 5ms/step
# Epoch 9/100
# 139/139 - 1s - loss: 0.0131 - 702ms/epoch - 5ms/step
# Epoch 10/100
# 139/139 - 1s - loss: 0.0121 - 725ms/epoch - 5ms/step
# Epoch 11/100
# 139/139 - 1s - loss: 0.0107 - 714ms/epoch - 5ms/step
# Epoch 12/100
# 139/139 - 1s - loss: 0.0094 - 717ms/epoch - 5ms/step
# Epoch 13/100
# 139/139 - 1s - loss: 0.0086 - 708ms/epoch - 5ms/step
# Epoch 14/100
# 139/139 - 1s - loss: 0.0097 - 710ms/epoch - 5ms/step
# Epoch 15/100
# 139/139 - 1s - loss: 0.0078 - 705ms/epoch - 5ms/step
# Epoch 16/100
# 139/139 - 1s - loss: 0.0076 - 707ms/epoch - 5ms/step
# Epoch 17/100
# 139/139 - 1s - loss: 0.0067 - 698ms/epoch - 5ms/step
# Epoch 18/100
# 139/139 - 1s - loss: 0.0067 - 709ms/epoch - 5ms/step
# Epoch 19/100
# 139/139 - 1s - loss: 0.0061 - 704ms/epoch - 5ms/step
# Epoch 20/100
# 139/139 - 1s - loss: 0.0065 - 736ms/epoch - 5ms/step
# Epoch 21/100
# 139/139 - 1s - loss: 0.0058 - 725ms/epoch - 5ms/step
# Epoch 22/100
# 139/139 - 1s - loss: 0.0062 - 693ms/epoch - 5ms/step
# Epoch 23/100
# 139/139 - 1s - loss: 0.0056 - 710ms/epoch - 5ms/step
# Epoch 24/100
# 139/139 - 1s - loss: 0.0057 - 719ms/epoch - 5ms/step
# Epoch 25/100
# 139/139 - 1s - loss: 0.0057 - 703ms/epoch - 5ms/step
# Epoch 26/100
# 139/139 - 1s - loss: 0.0057 - 732ms/epoch - 5ms/step
# Epoch 27/100
# 139/139 - 1s - loss: 0.0057 - 711ms/epoch - 5ms/step
# Epoch 28/100
# 139/139 - 1s - loss: 0.0059 - 704ms/epoch - 5ms/step
# Epoch 29/100
# 139/139 - 1s - loss: 0.0057 - 708ms/epoch - 5ms/step
# Epoch 30/100
# 139/139 - 1s - loss: 0.0055 - 706ms/epoch - 5ms/step
# Epoch 31/100
# 139/139 - 1s - loss: 0.0055 - 697ms/epoch - 5ms/step
# Epoch 32/100
# 139/139 - 1s - loss: 0.0056 - 750ms/epoch - 5ms/step
# Epoch 33/100
# 139/139 - 1s - loss: 0.0055 - 704ms/epoch - 5ms/step
# Epoch 34/100
# 139/139 - 1s - loss: 0.0056 - 632ms/epoch - 5ms/step
# Epoch 35/100
# 139/139 - 1s - loss: 0.0059 - 604ms/epoch - 4ms/step
# Epoch 36/100
# 139/139 - 1s - loss: 0.0057 - 612ms/epoch - 4ms/step
# Epoch 37/100
# 139/139 - 1s - loss: 0.0055 - 624ms/epoch - 4ms/step
# Epoch 38/100
# 139/139 - 1s - loss: 0.0054 - 619ms/epoch - 4ms/step
# Epoch 39/100
# 139/139 - 1s - loss: 0.0054 - 704ms/epoch - 5ms/step
# Epoch 40/100
# 139/139 - 1s - loss: 0.0054 - 709ms/epoch - 5ms/step
# Epoch 41/100
# 139/139 - 1s - loss: 0.0055 - 712ms/epoch - 5ms/step
# Epoch 42/100
# 139/139 - 1s - loss: 0.0056 - 691ms/epoch - 5ms/step
# Epoch 43/100
# 139/139 - 1s - loss: 0.0056 - 696ms/epoch - 5ms/step
# Epoch 44/100
# 139/139 - 1s - loss: 0.0054 - 721ms/epoch - 5ms/step
# Epoch 45/100
# 139/139 - 1s - loss: 0.0053 - 692ms/epoch - 5ms/step
# Epoch 46/100
# 139/139 - 1s - loss: 0.0052 - 698ms/epoch - 5ms/step
# Epoch 47/100
# 139/139 - 1s - loss: 0.0053 - 706ms/epoch - 5ms/step
# Epoch 48/100
# 139/139 - 1s - loss: 0.0053 - 734ms/epoch - 5ms/step
# Epoch 49/100
# 139/139 - 1s - loss: 0.0053 - 699ms/epoch - 5ms/step
# Epoch 50/100
# 139/139 - 1s - loss: 0.0052 - 748ms/epoch - 5ms/step
# Epoch 51/100
# 139/139 - 1s - loss: 0.0050 - 717ms/epoch - 5ms/step
# Epoch 52/100
# 139/139 - 1s - loss: 0.0050 - 711ms/epoch - 5ms/step
# Epoch 53/100
# 139/139 - 1s - loss: 0.0050 - 718ms/epoch - 5ms/step
# Epoch 54/100
# 139/139 - 1s - loss: 0.0050 - 714ms/epoch - 5ms/step
# Epoch 55/100
# 139/139 - 1s - loss: 0.0050 - 699ms/epoch - 5ms/step
# Epoch 56/100
# 139/139 - 1s - loss: 0.0049 - 695ms/epoch - 5ms/step
# Epoch 57/100
# 139/139 - 1s - loss: 0.0049 - 712ms/epoch - 5ms/step
# Epoch 58/100
# 139/139 - 1s - loss: 0.0048 - 699ms/epoch - 5ms/step
# Epoch 59/100
# 139/139 - 1s - loss: 0.0048 - 722ms/epoch - 5ms/step
# Epoch 60/100
# 139/139 - 1s - loss: 0.0048 - 696ms/epoch - 5ms/step
# Epoch 61/100
# 139/139 - 1s - loss: 0.0048 - 706ms/epoch - 5ms/step
# Epoch 62/100
# 139/139 - 1s - loss: 0.0047 - 703ms/epoch - 5ms/step
# Epoch 63/100
# 139/139 - 1s - loss: 0.0047 - 725ms/epoch - 5ms/step
# Epoch 64/100
# 139/139 - 1s - loss: 0.0047 - 730ms/epoch - 5ms/step
# Epoch 65/100
# 139/139 - 1s - loss: 0.0046 - 708ms/epoch - 5ms/step
# Epoch 66/100
# 139/139 - 1s - loss: 0.0046 - 708ms/epoch - 5ms/step
# Epoch 67/100
# 139/139 - 1s - loss: 0.0046 - 691ms/epoch - 5ms/step
# Epoch 68/100
# 139/139 - 1s - loss: 0.0046 - 706ms/epoch - 5ms/step
# Epoch 69/100
# 139/139 - 1s - loss: 0.0046 - 696ms/epoch - 5ms/step
# Epoch 70/100
# 139/139 - 1s - loss: 0.0047 - 709ms/epoch - 5ms/step
# Epoch 71/100
# 139/139 - 1s - loss: 0.0045 - 722ms/epoch - 5ms/step
# Epoch 72/100
# 139/139 - 1s - loss: 0.0047 - 705ms/epoch - 5ms/step
# Epoch 73/100
# 139/139 - 1s - loss: 0.0045 - 823ms/epoch - 6ms/step
# Epoch 74/100
# 139/139 - 1s - loss: 0.0046 - 750ms/epoch - 5ms/step
# Epoch 75/100
# 139/139 - 1s - loss: 0.0045 - 796ms/epoch - 6ms/step
# Epoch 76/100
# 139/139 - 1s - loss: 0.0046 - 751ms/epoch - 5ms/step
# Epoch 77/100
# 139/139 - 1s - loss: 0.0045 - 822ms/epoch - 6ms/step
# Epoch 78/100
# 139/139 - 1s - loss: 0.0045 - 1s/epoch - 8ms/step
# Epoch 79/100
# 139/139 - 1s - loss: 0.0045 - 811ms/epoch - 6ms/step
# Epoch 80/100
# 139/139 - 1s - loss: 0.0044 - 746ms/epoch - 5ms/step
# Epoch 81/100
# 139/139 - 1s - loss: 0.0044 - 760ms/epoch - 5ms/step
# Epoch 82/100
# 139/139 - 1s - loss: 0.0044 - 786ms/epoch - 6ms/step
# Epoch 83/100
# 139/139 - 1s - loss: 0.0044 - 751ms/epoch - 5ms/step
# Epoch 84/100
# 139/139 - 1s - loss: 0.0043 - 778ms/epoch - 6ms/step
# Epoch 85/100
# 139/139 - 1s - loss: 0.0044 - 747ms/epoch - 5ms/step
# Epoch 86/100
# 139/139 - 1s - loss: 0.0043 - 743ms/epoch - 5ms/step
# Epoch 87/100
# 139/139 - 1s - loss: 0.0043 - 720ms/epoch - 5ms/step
# Epoch 88/100
# 139/139 - 1s - loss: 0.0043 - 706ms/epoch - 5ms/step
# Epoch 89/100
# 139/139 - 1s - loss: 0.0043 - 699ms/epoch - 5ms/step
# Epoch 90/100
# 139/139 - 1s - loss: 0.0042 - 706ms/epoch - 5ms/step
# Epoch 91/100
# 139/139 - 1s - loss: 0.0042 - 696ms/epoch - 5ms/step
# Epoch 92/100
# 139/139 - 1s - loss: 0.0042 - 718ms/epoch - 5ms/step
# Epoch 93/100
# 139/139 - 1s - loss: 0.0042 - 686ms/epoch - 5ms/step
# Epoch 94/100
# 139/139 - 1s - loss: 0.0042 - 688ms/epoch - 5ms/step
# Epoch 95/100
# 139/139 - 1s - loss: 0.0043 - 707ms/epoch - 5ms/step
# Epoch 96/100
# 139/139 - 1s - loss: 0.0042 - 698ms/epoch - 5ms/step
# Epoch 97/100
# 139/139 - 1s - loss: 0.0041 - 724ms/epoch - 5ms/step
# Epoch 98/100
# 139/139 - 1s - loss: 0.0040 - 706ms/epoch - 5ms/step
# Epoch 99/100
# 139/139 - 1s - loss: 0.0041 - 696ms/epoch - 5ms/step
# Epoch 100/100
# 139/139 - 1s - loss: 0.0042 - 706ms/epoch - 5ms/step
# 1/1 [==============================] - 0s 410ms/step
# >expected=0.7, predicted=0.8
# MAE: 0.075

# %%
y1 = scaler1.inverse_transform(y.reshape(-1, 1))
yhat1 = scaler1.inverse_transform(yhat)
#data_new1 = scaler1.inverse_transform(data_new)

# %%
#yhat1

# %%
# plot expected vs predicted
pyplot.plot(y1, label='Expected')
pyplot.plot(yhat1, label='Predicted')
pyplot.legend()
pyplot.show()

# %%
def smape_kun(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))*100

# %%
predictions = yhat1

# %%
exp_predictions = np.exp(predictions)
exp_spot= np.exp(spot)
exp_test = np.exp(test)
exp_train = np.exp(train)

x_axis = np.arange(exp_spot.shape[0])
n_test = exp_predictions.shape[0]

plt.plot(x_axis, exp_spot, alpha=0.75, c='b')
plt.plot(x_axis[-n_test:], exp_predictions, alpha=0.75, c='g')  # Forecasts
plt.title("Cross-validated forecasts")
plt.show()

# %%
error = mean_squared_error(exp_test, exp_predictions)
print('Mean Squared Error: %.3f' % error)
error2 = mean_absolute_error(exp_test, exp_predictions)
print('Mean Absolute Error: %.3f' % error2)
error3 = mean_absolute_percentage_error(exp_test, exp_predictions)
print('Mean Absolute Percentage Error: %.3f' % (error3*100))
error4 = smape_kun(exp_test, exp_predictions)
print('Symmetric Mean Absolute Percentage Error: %.3f' % error4)
# Out:
# Mean Squared Error: 88.141
# Mean Absolute Error: 6.948
# Mean Absolute Percentage Error: 12.004
# Symmetric Mean Absolute Percentage Error: 32.019

# %%
### same with built-in function ###

#predictions22 = model_selection.cross_val_score(
#    ar, spot, scoring='mean_absolute_error', cv=cv, verbose=0)
#np.average(predictions22)

# %%
#### MASE ###

abs_errors = abs(exp_predictions - exp_test)
mae_naive_list = []

for x in range(len(exp_test)):
    insample_data = exp_spot[x:-(len(exp_test)-x)]
    mae_insample = np.mean(abs(insample_data.diff().dropna()))
    mae_naive_list.append(mae_insample)

mase = np.mean(abs_errors / mae_naive_list)

print('Mean Absolute Scaled Error: %.3f' % mase)
# Out:
# Mean Absolute Scaled Error: 4.151

# %%
### Returns ###

returns = []

test_app2 = list(exp_test)
test_app2.insert(0, exp_train[-1]) ## append last of train data
price_moves = np.array(pd.DataFrame(test_app2).pct_change().dropna()+1)

pred_app2 = list(predictions)

test_shift2 = list(test)
test_shift2.insert(0, train[-1])
test_shift2.pop()

dir_pred2 = np.array(np.sign([a - b for a, b in zip(pred_app2,test_shift2)]))

for t in range(len(dir_pred2)):
    if dir_pred2[t] == 1:
            returns.append(price_moves[t])
        
    if dir_pred2[t] == -1:
        returns.append(1/price_moves[t])

returns = pd.DataFrame(returns)
returns
# Out:
#            0
# 0   0.902636
# 1   1.042942
# 2   0.984509
# 3   0.957004
# 4   0.888244
# ..       ...
# 71  1.043632
# 72  0.877102
# 73  1.096976
# 74  0.927555
# 75  0.900875
#
# [76 rows x 1 columns]

# %%
### Returns t-test ###

t_statistic, p_value = stats.ttest_1samp(a=returns, popmean=1, alternative='greater') ### one tailed test?


print(t_statistic , p_value)
# Out:
# [0.317269] [0.37596052]

# %%
### Merton test ###

test_app = list(test)
test_app.insert(0, train[-1]) ## append last of train data
dir = np.array(np.sign(pd.DataFrame(test_app).diff().dropna()))

pred_app = list(predictions)

test_shift = list(test)
test_shift.insert(0, train[-1])
test_shift.pop()

dir_pred = np.array(np.sign([a - b for a, b in zip(pred_app,test_shift)]))

q_minus = 0
q_plus = 0
pred_minus = 0
pred_plus = 0

for t in range(len(dir)):
    if dir[t] == 1:
        q_plus += 1
        if dir_pred[t] == 1:
            pred_plus += 1
    if dir[t] == -1:
        q_minus += 1
        if dir_pred[t] == -1:
            pred_minus += 1

print('Merton test: %.3f' % ((pred_plus / q_plus) + (pred_minus / q_minus)))
# Out:
# Merton test: 0.858

# %%
len(test)
# Out:
# 76
