# %%
# Start loading libraries

#! pip install yfinance

# ! conda install seaborn

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import scipy
import scipy.stats as stats
import statsmodels.api as sm

import scipy
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

import pmdarima as pm
from pmdarima import model_selection
from pmdarima.model_selection import SlidingWindowForecastCV

from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error


from scipy.optimize import minimize
from random import gauss
import math
from statistics import mean, stdev

from numpy import asarray
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot


#! pip install tensorflow --user
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler

#from statsmodels.graphics.tsaplots import plot_acf

#from matplotlib.ticker import NullFormatter
#import yfinance as yf
#import warnings; warnings.simplefilter('ignore')
#%matplotlib inline

# %%
xls_file = pd.ExcelFile("Data_monthly_final.xlsx") # Read Excel
df1=xls_file.parse("Brent") # Read the first sheet (Portfolio holdings)

#df1["Timestamp"] = df1["Date"].astype('datetime64[ns]') # Convert column to date format
df1 = df1.set_index(['Timestamp']) # use first column as index

#df1.to_excel("values.xlsx")  #print to excel

# %%
spot = df1["LCOc1"]
spot = np.log(spot)
spot = spot.loc['2004-01-31':'2022-11-30']
spot_train = spot.loc[:'2016-07-31']
#spot_train.plot()

# %%
# transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
 #n_vars = 1 if type(data) is list else data.shape[1]
 df_temp = pd.DataFrame(data)
 cols = list()
 # input sequence (t-n, ... t-1)
 for i in range(n_in, 0, -1):
    cols.append(df_temp.shift(i))
 # forecast sequence (t, t+1, ... t+n)
 for i in range(0, n_out):
    cols.append(df_temp.shift(-i))
 # put it all together
 agg = pd.concat(cols, axis=1)
 # drop rows with NaN values
 if dropnan:
    agg.dropna(inplace=True)
 return agg.values

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %%
# fix random seed for reproducibility
tf.random.set_seed(7)

# Load the data and split it into separate pieces
data = np.array(spot.dropna())
train, test = model_selection.train_test_split(data, train_size=(spot_train.shape[0]))

# normalize the dataset
scaler1 = MinMaxScaler(feature_range=(0, 1)).fit(train.reshape(-1, 1))  ### using only train data in the scaling
data_scaled = scaler1.transform(data.reshape(-1, 1))

time_lag = 1

data_new = series_to_supervised(data_scaled, n_in=time_lag, n_out=1, dropnan=True)
#train, test = model_selection.train_test_split(data, train_size=(spot.shape[0]-1))

# %%
#data_scaled1 = scaler1.inverse_transform(data_scaled)
#np.exp(data_scaled1)

# %%
#train_new  = series_to_supervised(train, n_in=time_lag, n_out=1, dropnan=True)
#test_new = series_to_supervised(test, n_in=time_lag, n_out=1, dropnan=True)

# %%
# fit an lstm model and make a one step prediction
def lstm_forecast(trainlocal, testX):
 # transform list into array
 trainlocalar = asarray(trainlocal)
 # split into input and output columns
 trainX, trainy = trainlocalar[:, :-1], trainlocalar[:, -1]

 # reshape input to be [samples, time steps, features]
 trainX = np.reshape(trainX, (trainX.shape[0], 1 , trainX.shape[1]))
 testX = np.reshape(testX, (testX.shape[0], 1 , trainX.shape[1]))     #### PURKKARATKAISU ###

 # create and fit the LSTM network
 model = Sequential()
 model.add(LSTM(4, input_shape=(1, time_lag)))
 #model.add(LSTM(4, input_shape=(1, time_lag), stateful = True))
 model.add(Dense(1))
 model.compile(loss='mean_squared_error', optimizer='adam')
 model.fit(trainX, trainy, epochs=100, batch_size=1, verbose=2)
 #model.fit(trainX, trainy, epochs=1, batch_size=1, verbose=2)
 
  # make a one-step prediction
 yhat = model.predict([testX])
 return yhat[0]

# %%
# walk-forward validation for univariate data
def walk_forward_validation(data, n_test):
   predictions = list()
   # split dataset
   train1, test1 = train_test_split(data, n_test)
   # seed history with training dataset
   history = [x for x in train1]
   # step over each time-step in the test set
   for i in range(len(test1)):
      # split test row into input and output columns
      testX, testy = test1[i, :-1], test1[i, -1]
      # fit model on history and make a prediction
      yhat = lstm_forecast(history, testX)
      # store forecast in list of predictions
      predictions.append(yhat)
      # add actual observation to history for the next loop and delete oldest one
      history.append(test1[i])
      history.pop(0)
      # summarize progress
      print('>expected=%.1f, predicted=%.1f' % (testy, yhat))

    # estimate prediction error
   error = mean_absolute_error(test1[:, -1], predictions)
   return error, test1[:, -1], predictions

# %%
# evaluate
mae, y, yhat = walk_forward_validation(data_new, len(test))
#mae, y, yhat = walk_forward_validation(data_new, 2)
print('MAE: %.3f' % mae)
# Out:
# Epoch 1/100
# 150/150 - 1s - loss: 0.2226 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0573 - 241ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0249 - 243ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0212 - 248ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0184 - 239ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0153 - 233ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0127 - 260ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0105 - 259ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0085 - 247ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0068 - 262ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0056 - 236ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0048 - 235ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0042 - 230ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0038 - 244ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0036 - 241ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0035 - 258ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0035 - 269ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 268ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0034 - 272ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0035 - 265ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0034 - 265ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 251ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0033 - 231ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0035 - 235ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0034 - 266ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 300ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0034 - 285ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 265ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0034 - 250ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0034 - 260ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 256ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 288ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0033 - 288ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0035 - 222ms/epoch - 1ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0035 - 230ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0034 - 285ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0034 - 268ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0033 - 233ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0033 - 228ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0035 - 228ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0034 - 215ms/epoch - 1ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0033 - 226ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 213ms/epoch - 1ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0035 - 227ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0035 - 227ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 222ms/epoch - 1ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0035 - 224ms/epoch - 1ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0034 - 222ms/epoch - 1ms/step
# 1/1 [==============================] - 0s 314ms/step
# >expected=0.3, predicted=0.3
# C:\Users\tatuh\AppData\Local\Temp\ipykernel_3316\3682001088.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
# Epoch 1/100
# 150/150 - 1s - loss: 0.1357 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0237 - 241ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0150 - 241ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0126 - 252ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0106 - 262ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0087 - 260ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0071 - 237ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0058 - 239ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0049 - 254ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0043 - 243ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0040 - 245ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0036 - 242ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0036 - 246ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0034 - 247ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0034 - 251ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0035 - 246ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0033 - 233ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0035 - 246ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0035 - 227ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0033 - 236ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0033 - 232ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0035 - 243ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0035 - 252ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0035 - 253ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0035 - 230ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0035 - 245ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0035 - 239ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 225ms/epoch - 1ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0035 - 235ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0033 - 236ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0035 - 239ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0036 - 243ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0036 - 231ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 315ms/step
# >expected=0.3, predicted=0.3
# Epoch 1/100
# 150/150 - 1s - loss: 0.2131 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0556 - 236ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0247 - 236ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0211 - 231ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0183 - 235ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0156 - 221ms/epoch - 1ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0130 - 240ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0107 - 251ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0088 - 241ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0071 - 224ms/epoch - 1ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0060 - 237ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0050 - 235ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0043 - 230ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0039 - 238ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0037 - 232ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0036 - 244ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0033 - 237ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0035 - 223ms/epoch - 1ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0033 - 241ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0035 - 253ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 254ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0035 - 249ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0036 - 257ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 217ms/epoch - 1ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0036 - 245ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0033 - 244ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0035 - 244ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0036 - 233ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0034 - 221ms/epoch - 1ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0033 - 230ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0033 - 245ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0035 - 244ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0035 - 229ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0035 - 243ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0034 - 251ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0035 - 249ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0034 - 247ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0035 - 239ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0035 - 244ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0034 - 251ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 310ms/step
# >expected=0.3, predicted=0.3
# Epoch 1/100
# 150/150 - 1s - loss: 0.2776 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0825 - 232ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0333 - 238ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0269 - 243ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0240 - 237ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0212 - 242ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0184 - 233ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0159 - 236ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0135 - 232ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0114 - 246ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0097 - 240ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0081 - 232ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0066 - 240ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0058 - 233ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0050 - 233ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0044 - 242ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0039 - 254ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0037 - 239ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0037 - 252ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0034 - 224ms/epoch - 1ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0033 - 237ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0033 - 252ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0033 - 230ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0034 - 259ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0034 - 219ms/epoch - 1ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0033 - 241ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0034 - 223ms/epoch - 1ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0035 - 243ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0035 - 237ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0035 - 229ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0033 - 232ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0035 - 245ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0033 - 244ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0035 - 228ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0035 - 235ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0033 - 248ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0035 - 226ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0033 - 235ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0035 - 228ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 313ms/step
# >expected=0.3, predicted=0.3
# Epoch 1/100
# 150/150 - 1s - loss: 0.3259 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.1199 - 235ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0460 - 240ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0330 - 228ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0296 - 238ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0265 - 238ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0232 - 232ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0201 - 227ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0172 - 239ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0145 - 233ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0121 - 235ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0100 - 231ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0082 - 238ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0067 - 239ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0056 - 233ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0048 - 240ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0041 - 237ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0040 - 230ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0037 - 232ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0035 - 246ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0034 - 223ms/epoch - 1ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0036 - 245ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0034 - 245ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0033 - 235ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0035 - 223ms/epoch - 1ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0034 - 225ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0034 - 255ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0035 - 238ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0033 - 226ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 341ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0035 - 228ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 255ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0033 - 241ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0035 - 226ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0034 - 248ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0033 - 225ms/epoch - 1ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0034 - 252ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 311ms/step
# >expected=0.4, predicted=0.4
# Epoch 1/100
# 150/150 - 1s - loss: 0.2770 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0954 - 232ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0344 - 234ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0263 - 228ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0239 - 233ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0215 - 238ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0191 - 237ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0168 - 246ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0144 - 238ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0125 - 230ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0107 - 225ms/epoch - 1ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0090 - 231ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0075 - 234ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0064 - 244ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0054 - 230ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0047 - 231ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0042 - 231ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0040 - 232ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0037 - 239ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0035 - 239ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0033 - 240ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0035 - 227ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0033 - 245ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0035 - 245ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 242ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0035 - 231ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0033 - 227ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0033 - 224ms/epoch - 1ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 246ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0033 - 222ms/epoch - 1ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0033 - 223ms/epoch - 1ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0035 - 232ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0034 - 225ms/epoch - 1ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0033 - 233ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 224ms/epoch - 1ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0036 - 228ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0035 - 242ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0033 - 230ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0035 - 237ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 244ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0034 - 241ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0033 - 235ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0034 - 222ms/epoch - 1ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0033 - 240ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0033 - 229ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0035 - 239ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0036 - 226ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 314ms/step
# >expected=0.4, predicted=0.4
# Epoch 1/100
# 150/150 - 1s - loss: 0.1585 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0338 - 237ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0161 - 231ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0139 - 232ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0121 - 233ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0106 - 236ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0089 - 223ms/epoch - 1ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0075 - 234ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0063 - 232ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0054 - 235ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0046 - 232ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0042 - 240ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0038 - 236ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0037 - 232ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0034 - 252ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0033 - 230ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0033 - 240ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0035 - 241ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0033 - 227ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0033 - 240ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0033 - 217ms/epoch - 1ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0034 - 243ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0033 - 234ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0034 - 236ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0035 - 247ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0034 - 224ms/epoch - 1ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0035 - 218ms/epoch - 1ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0034 - 247ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0033 - 231ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0033 - 230ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0033 - 229ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0034 - 238ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0035 - 240ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0033 - 220ms/epoch - 1ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0034 - 224ms/epoch - 1ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0035 - 227ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0034 - 226ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0034 - 228ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0033 - 228ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0035 - 221ms/epoch - 1ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0033 - 233ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0034 - 225ms/epoch - 1ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0034 - 220ms/epoch - 1ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0033 - 229ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0034 - 231ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0035 - 233ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0034 - 250ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0035 - 243ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0033 - 238ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0034 - 234ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0034 - 249ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0034 - 230ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0033 - 245ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0033 - 242ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0034 - 229ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0034 - 239ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0034 - 233ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0034 - 240ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0033 - 226ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0033 - 231ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0035 - 236ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0035 - 219ms/epoch - 1ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0034 - 220ms/epoch - 1ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0034 - 237ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0035 - 234ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0034 - 227ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0034 - 235ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0035 - 237ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0034 - 232ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 314ms/step
# >expected=0.4, predicted=0.4
# Epoch 1/100
# 150/150 - 2s - loss: 0.2081 - 2s/epoch - 12ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.0505 - 234ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0214 - 230ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0187 - 243ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0165 - 244ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0145 - 248ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0123 - 249ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0103 - 238ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0086 - 243ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0072 - 243ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0061 - 239ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0052 - 250ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0045 - 246ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0041 - 237ms/epoch - 2ms/step
# Epoch 15/100
# ...
# 150/150 - 0s - loss: 0.0049 - 269ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0050 - 278ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0049 - 264ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0049 - 259ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0049 - 279ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0048 - 256ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0049 - 258ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0047 - 265ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0048 - 263ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0049 - 270ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0048 - 257ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0048 - 283ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0048 - 273ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0047 - 265ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0049 - 262ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0048 - 259ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0049 - 272ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0048 - 257ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0049 - 273ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0048 - 267ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0049 - 260ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0048 - 269ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0047 - 261ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0048 - 259ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0047 - 273ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0048 - 257ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0049 - 257ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0048 - 267ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0047 - 257ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0049 - 260ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0049 - 250ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 316ms/step
# >expected=0.7, predicted=0.8
# Epoch 1/100
# 150/150 - 1s - loss: 0.2908 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.1194 - 265ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0473 - 275ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0297 - 266ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0256 - 264ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0229 - 273ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0200 - 262ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0172 - 276ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0144 - 286ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0121 - 267ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0100 - 283ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0082 - 264ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0068 - 265ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0060 - 266ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0054 - 271ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0051 - 276ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0049 - 279ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0049 - 280ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0048 - 275ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0048 - 271ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0049 - 279ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0048 - 267ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0047 - 272ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0048 - 264ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0049 - 270ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0049 - 270ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0048 - 259ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0048 - 256ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0049 - 258ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0048 - 286ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0048 - 271ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0048 - 266ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0048 - 264ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0048 - 257ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0048 - 261ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0048 - 267ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0050 - 267ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0048 - 269ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0048 - 266ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0047 - 256ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0048 - 274ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0048 - 249ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0048 - 271ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0049 - 250ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0048 - 266ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0048 - 254ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0048 - 264ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0047 - 256ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0048 - 266ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0048 - 267ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0049 - 254ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0048 - 269ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0049 - 265ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0049 - 284ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0048 - 258ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0048 - 283ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0048 - 264ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0048 - 271ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0049 - 267ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0049 - 275ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0049 - 283ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0048 - 278ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0048 - 282ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0049 - 271ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0048 - 264ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0048 - 266ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0048 - 280ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0049 - 275ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0048 - 273ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0048 - 268ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0048 - 278ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0048 - 276ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0049 - 271ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0047 - 282ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0049 - 271ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0047 - 264ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0049 - 264ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0048 - 256ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 314ms/step
# >expected=0.8, predicted=0.7
# Epoch 1/100
# 150/150 - 1s - loss: 0.3169 - 1s/epoch - 9ms/step
# Epoch 2/100
# 150/150 - 0s - loss: 0.1587 - 263ms/epoch - 2ms/step
# Epoch 3/100
# 150/150 - 0s - loss: 0.0780 - 265ms/epoch - 2ms/step
# Epoch 4/100
# 150/150 - 0s - loss: 0.0479 - 262ms/epoch - 2ms/step
# Epoch 5/100
# 150/150 - 0s - loss: 0.0391 - 260ms/epoch - 2ms/step
# Epoch 6/100
# 150/150 - 0s - loss: 0.0354 - 260ms/epoch - 2ms/step
# Epoch 7/100
# 150/150 - 0s - loss: 0.0316 - 257ms/epoch - 2ms/step
# Epoch 8/100
# 150/150 - 0s - loss: 0.0274 - 254ms/epoch - 2ms/step
# Epoch 9/100
# 150/150 - 0s - loss: 0.0225 - 264ms/epoch - 2ms/step
# Epoch 10/100
# 150/150 - 0s - loss: 0.0177 - 274ms/epoch - 2ms/step
# Epoch 11/100
# 150/150 - 0s - loss: 0.0131 - 249ms/epoch - 2ms/step
# Epoch 12/100
# 150/150 - 0s - loss: 0.0095 - 249ms/epoch - 2ms/step
# Epoch 13/100
# 150/150 - 0s - loss: 0.0070 - 245ms/epoch - 2ms/step
# Epoch 14/100
# 150/150 - 0s - loss: 0.0058 - 258ms/epoch - 2ms/step
# Epoch 15/100
# 150/150 - 0s - loss: 0.0052 - 254ms/epoch - 2ms/step
# Epoch 16/100
# 150/150 - 0s - loss: 0.0049 - 248ms/epoch - 2ms/step
# Epoch 17/100
# 150/150 - 0s - loss: 0.0048 - 253ms/epoch - 2ms/step
# Epoch 18/100
# 150/150 - 0s - loss: 0.0049 - 270ms/epoch - 2ms/step
# Epoch 19/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 20/100
# 150/150 - 0s - loss: 0.0048 - 259ms/epoch - 2ms/step
# Epoch 21/100
# 150/150 - 0s - loss: 0.0049 - 255ms/epoch - 2ms/step
# Epoch 22/100
# 150/150 - 0s - loss: 0.0047 - 249ms/epoch - 2ms/step
# Epoch 23/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 24/100
# 150/150 - 0s - loss: 0.0049 - 251ms/epoch - 2ms/step
# Epoch 25/100
# 150/150 - 0s - loss: 0.0049 - 251ms/epoch - 2ms/step
# Epoch 26/100
# 150/150 - 0s - loss: 0.0048 - 271ms/epoch - 2ms/step
# Epoch 27/100
# 150/150 - 0s - loss: 0.0049 - 256ms/epoch - 2ms/step
# Epoch 28/100
# 150/150 - 0s - loss: 0.0049 - 265ms/epoch - 2ms/step
# Epoch 29/100
# 150/150 - 0s - loss: 0.0049 - 257ms/epoch - 2ms/step
# Epoch 30/100
# 150/150 - 0s - loss: 0.0048 - 261ms/epoch - 2ms/step
# Epoch 31/100
# 150/150 - 0s - loss: 0.0049 - 258ms/epoch - 2ms/step
# Epoch 32/100
# 150/150 - 0s - loss: 0.0048 - 253ms/epoch - 2ms/step
# Epoch 33/100
# 150/150 - 0s - loss: 0.0049 - 256ms/epoch - 2ms/step
# Epoch 34/100
# 150/150 - 0s - loss: 0.0048 - 269ms/epoch - 2ms/step
# Epoch 35/100
# 150/150 - 0s - loss: 0.0049 - 255ms/epoch - 2ms/step
# Epoch 36/100
# 150/150 - 0s - loss: 0.0048 - 242ms/epoch - 2ms/step
# Epoch 37/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 38/100
# 150/150 - 0s - loss: 0.0049 - 257ms/epoch - 2ms/step
# Epoch 39/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 40/100
# 150/150 - 0s - loss: 0.0049 - 265ms/epoch - 2ms/step
# Epoch 41/100
# 150/150 - 0s - loss: 0.0049 - 241ms/epoch - 2ms/step
# Epoch 42/100
# 150/150 - 0s - loss: 0.0048 - 245ms/epoch - 2ms/step
# Epoch 43/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 44/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 45/100
# 150/150 - 0s - loss: 0.0048 - 251ms/epoch - 2ms/step
# Epoch 46/100
# 150/150 - 0s - loss: 0.0050 - 256ms/epoch - 2ms/step
# Epoch 47/100
# 150/150 - 0s - loss: 0.0048 - 261ms/epoch - 2ms/step
# Epoch 48/100
# 150/150 - 0s - loss: 0.0048 - 260ms/epoch - 2ms/step
# Epoch 49/100
# 150/150 - 0s - loss: 0.0049 - 256ms/epoch - 2ms/step
# Epoch 50/100
# 150/150 - 0s - loss: 0.0048 - 253ms/epoch - 2ms/step
# Epoch 51/100
# 150/150 - 0s - loss: 0.0048 - 296ms/epoch - 2ms/step
# Epoch 52/100
# 150/150 - 0s - loss: 0.0048 - 273ms/epoch - 2ms/step
# Epoch 53/100
# 150/150 - 0s - loss: 0.0049 - 250ms/epoch - 2ms/step
# Epoch 54/100
# 150/150 - 0s - loss: 0.0048 - 261ms/epoch - 2ms/step
# Epoch 55/100
# 150/150 - 0s - loss: 0.0048 - 260ms/epoch - 2ms/step
# Epoch 56/100
# 150/150 - 0s - loss: 0.0048 - 253ms/epoch - 2ms/step
# Epoch 57/100
# 150/150 - 0s - loss: 0.0048 - 265ms/epoch - 2ms/step
# Epoch 58/100
# 150/150 - 0s - loss: 0.0048 - 296ms/epoch - 2ms/step
# Epoch 59/100
# 150/150 - 0s - loss: 0.0048 - 303ms/epoch - 2ms/step
# Epoch 60/100
# 150/150 - 0s - loss: 0.0049 - 272ms/epoch - 2ms/step
# Epoch 61/100
# 150/150 - 0s - loss: 0.0048 - 246ms/epoch - 2ms/step
# Epoch 62/100
# 150/150 - 0s - loss: 0.0049 - 272ms/epoch - 2ms/step
# Epoch 63/100
# 150/150 - 0s - loss: 0.0048 - 252ms/epoch - 2ms/step
# Epoch 64/100
# 150/150 - 0s - loss: 0.0048 - 256ms/epoch - 2ms/step
# Epoch 65/100
# 150/150 - 0s - loss: 0.0048 - 272ms/epoch - 2ms/step
# Epoch 66/100
# 150/150 - 0s - loss: 0.0048 - 263ms/epoch - 2ms/step
# Epoch 67/100
# 150/150 - 0s - loss: 0.0048 - 253ms/epoch - 2ms/step
# Epoch 68/100
# 150/150 - 0s - loss: 0.0048 - 260ms/epoch - 2ms/step
# Epoch 69/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 70/100
# 150/150 - 0s - loss: 0.0049 - 248ms/epoch - 2ms/step
# Epoch 71/100
# 150/150 - 0s - loss: 0.0050 - 263ms/epoch - 2ms/step
# Epoch 72/100
# 150/150 - 0s - loss: 0.0049 - 258ms/epoch - 2ms/step
# Epoch 73/100
# 150/150 - 0s - loss: 0.0049 - 251ms/epoch - 2ms/step
# Epoch 74/100
# 150/150 - 0s - loss: 0.0049 - 261ms/epoch - 2ms/step
# Epoch 75/100
# 150/150 - 0s - loss: 0.0048 - 255ms/epoch - 2ms/step
# Epoch 76/100
# 150/150 - 0s - loss: 0.0049 - 265ms/epoch - 2ms/step
# Epoch 77/100
# 150/150 - 0s - loss: 0.0048 - 286ms/epoch - 2ms/step
# Epoch 78/100
# 150/150 - 0s - loss: 0.0049 - 254ms/epoch - 2ms/step
# Epoch 79/100
# 150/150 - 0s - loss: 0.0049 - 270ms/epoch - 2ms/step
# Epoch 80/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 81/100
# 150/150 - 0s - loss: 0.0049 - 258ms/epoch - 2ms/step
# Epoch 82/100
# 150/150 - 0s - loss: 0.0049 - 263ms/epoch - 2ms/step
# Epoch 83/100
# 150/150 - 0s - loss: 0.0049 - 262ms/epoch - 2ms/step
# Epoch 84/100
# 150/150 - 0s - loss: 0.0048 - 259ms/epoch - 2ms/step
# Epoch 85/100
# 150/150 - 0s - loss: 0.0048 - 278ms/epoch - 2ms/step
# Epoch 86/100
# 150/150 - 0s - loss: 0.0049 - 267ms/epoch - 2ms/step
# Epoch 87/100
# 150/150 - 0s - loss: 0.0048 - 258ms/epoch - 2ms/step
# Epoch 88/100
# 150/150 - 0s - loss: 0.0048 - 250ms/epoch - 2ms/step
# Epoch 89/100
# 150/150 - 0s - loss: 0.0048 - 260ms/epoch - 2ms/step
# Epoch 90/100
# 150/150 - 0s - loss: 0.0048 - 261ms/epoch - 2ms/step
# Epoch 91/100
# 150/150 - 0s - loss: 0.0049 - 263ms/epoch - 2ms/step
# Epoch 92/100
# 150/150 - 0s - loss: 0.0049 - 255ms/epoch - 2ms/step
# Epoch 93/100
# 150/150 - 0s - loss: 0.0049 - 247ms/epoch - 2ms/step
# Epoch 94/100
# 150/150 - 0s - loss: 0.0048 - 270ms/epoch - 2ms/step
# Epoch 95/100
# 150/150 - 0s - loss: 0.0048 - 249ms/epoch - 2ms/step
# Epoch 96/100
# 150/150 - 0s - loss: 0.0049 - 253ms/epoch - 2ms/step
# Epoch 97/100
# 150/150 - 0s - loss: 0.0048 - 240ms/epoch - 2ms/step
# Epoch 98/100
# 150/150 - 0s - loss: 0.0048 - 250ms/epoch - 2ms/step
# Epoch 99/100
# 150/150 - 0s - loss: 0.0048 - 251ms/epoch - 2ms/step
# Epoch 100/100
# 150/150 - 0s - loss: 0.0048 - 238ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 316ms/step
# >expected=0.7, predicted=0.7
# MAE: 0.055

# %%
y1 = scaler1.inverse_transform(y.reshape(-1, 1))
yhat1 = scaler1.inverse_transform(yhat)
#data_new1 = scaler1.inverse_transform(data_new)

# %%
#yhat1

# %%
# plot expected vs predicted
pyplot.plot(y1, label='Expected')
pyplot.plot(yhat1, label='Predicted')
pyplot.legend()
pyplot.show()

# %%
def smape_kun(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true) / ((np.abs(y_pred) + np.abs(y_true))/2))*100

# %%
predictions = yhat1

# %%
exp_predictions = np.exp(predictions)
exp_spot= np.exp(spot)
exp_test = np.exp(test)
exp_train = np.exp(train)

x_axis = np.arange(exp_spot.shape[0])
n_test = exp_predictions.shape[0]

plt.plot(x_axis, exp_spot, alpha=0.75, c='b')
plt.plot(x_axis[-n_test:], exp_predictions, alpha=0.75, c='g')  # Forecasts
plt.title("Cross-validated forecasts")
plt.show()

# %%
error = mean_squared_error(exp_test, exp_predictions)
print('Mean Squared Error: %.3f' % error)
error2 = mean_absolute_error(exp_test, exp_predictions)
print('Mean Absolute Error: %.3f' % error2)
error3 = mean_absolute_percentage_error(exp_test, exp_predictions)
print('Mean Absolute Percentage Error: %.3f' % (error3*100))
error4 = smape_kun(exp_test, exp_predictions)
print('Symmetric Mean Absolute Percentage Error: %.3f' % error4)
# Out:
# Mean Squared Error: 50.431
# Mean Absolute Error: 5.383
# Mean Absolute Percentage Error: 9.134
# Symmetric Mean Absolute Percentage Error: 31.757

# %%
### same with built-in function ###

#predictions22 = model_selection.cross_val_score(
#    ar, spot, scoring='mean_absolute_error', cv=cv, verbose=0)
#np.average(predictions22)

# %%
#### MASE ###

abs_errors = abs(exp_predictions - exp_test)
mae_naive_list = []

for x in range(len(exp_test)):
    insample_data = exp_spot[x:-(len(exp_test)-x)]
    mae_insample = np.mean(abs(insample_data.diff().dropna()))
    mae_naive_list.append(mae_insample)

mase = np.mean(abs_errors / mae_naive_list)

print('Mean Absolute Scaled Error: %.3f' % mase)
# Out:
# Mean Absolute Scaled Error: 4.163

# %%
### Returns ###

returns = []

test_app2 = list(exp_test)
test_app2.insert(0, exp_train[-1]) ## append last of train data
price_moves = np.array(pd.DataFrame(test_app2).pct_change().dropna()+1)

pred_app2 = list(predictions)

test_shift2 = list(test)
test_shift2.insert(0, train[-1])
test_shift2.pop()

dir_pred2 = np.array(np.sign([a - b for a, b in zip(pred_app2,test_shift2)]))

for t in range(len(dir_pred2)):
    if dir_pred2[t] == 1:
            returns.append(price_moves[t])
        
    if dir_pred2[t] == -1:
        returns.append(1/price_moves[t])

returns = pd.DataFrame(returns)
returns
# Out:
#            0
# 0   1.107866
# 1   1.042942
# 2   0.984509
# 3   1.044928
# 4   1.125817
# ..       ...
# 71  0.958192
# 72  0.877102
# 73  1.096976
# 74  0.927555
# 75  1.110032
#
# [76 rows x 1 columns]

# %%
### Returns t-test ###

t_statistic, p_value = stats.ttest_1samp(a=returns, popmean=1, alternative='greater') ### one tailed test?


print(t_statistic , p_value)
# Out:
# [0.05042593] [0.47995852]

# %%
### Merton test ###

test_app = list(test)
test_app.insert(0, train[-1]) ## append last of train data
dir = np.array(np.sign(pd.DataFrame(test_app).diff().dropna()))

pred_app = list(predictions)

test_shift = list(test)
test_shift.insert(0, train[-1])
test_shift.pop()

dir_pred = np.array(np.sign([a - b for a, b in zip(pred_app,test_shift)]))

q_minus = 0
q_plus = 0
pred_minus = 0
pred_plus = 0

for t in range(len(dir)):
    if dir[t] == 1:
        q_plus += 1
        if dir_pred[t] == 1:
            pred_plus += 1
    if dir[t] == -1:
        q_minus += 1
        if dir_pred[t] == -1:
            pred_minus += 1

print('Merton test: %.3f' % ((pred_plus / q_plus) + (pred_minus / q_minus)))
# Out:
# Merton test: 0.887

# %%
len(test)
# Out:
# 76
